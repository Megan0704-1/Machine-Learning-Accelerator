# %% [markdown]
# <a href="https://colab.research.google.com/github/ML-HW-SYS/a2/blob/main/5_quantization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Quantization** (50 pts)

# %% [markdown]
# This module utilizes the trained model from the previous section to perform quantization so as to improve the execution efficiency of the model. There are two main quantization techniques here:
#
# 1. Post Training Quantization (PTQ)
#
# 2. Quantization Aware Training (QAT)

# %% [markdown]
# # 1.1 Understanding Audio Processing
#
# The DNN in the first part of this lab (1_quantization.pynb) works on audio data. The main task of the DNN is to detect and classify sound waves using audio files. The dataset we will be using contains multiple audio recordings and the DNN classifies them into 4 categories: Loud Yes, Loud No, Quiet Yes, Quiet No.
#
# For any deep learning model exercise, it is best to first understand the input data modality. In our case, its audio files (.wav). Audio files can be directly processed as time series data, or converted into frequency domain and processed as images. Below are some visualizations for the audio data from the dataset we will be using. These visualizations are only meant to understand the data.
#
# The dataset is already provided to you. You don't need to download it.

# %% [markdown]
# ## Time domain visualization
#
# This part of the notebook represents the .wav audio samples as signals plotted on a graph. The x-axis of the graphs represents time and is derived using frame rate. The graphs depict the magnitudes of the sound of the audio samples.
#
# ![time_domain.png](attachment:fd886e44-f0eb-4133-b23a-f467d837a521.png)

# %% [markdown]
# ## Frequency domain visualization
#
# Here, the audio samples are displayed in the frequency domain through Fourier transformations. The x axis, instead of representing time, now represents frequency, and the y axis represents the amount of decibels in the sample at each frequency.
#
# Adapted from: https://makersportal.com/blog/2018/9/13/audio-processing-in-python-part-i-sampling-and-the-fast-fourier-transform
#
# ![Frequency_domain.png](attachment:2b63960f-fc71-4dff-967c-9a4ff3dd2c0b.png)

# %% [markdown]
# ## Spectogram
#
# A spectogram is a figure which visually represents the spectrum of frequencies of a recorded audio over time. This part of the notebook produces those "pictures" of your audio samples. Brighter color indicates more concentration around specific frequencies. They are important in machine learning since they capture the shape and structure of audio in a format algorithms can manipulate.
#
# For more information on spectrograms use in ML, checkout: [Learning from Audio: Spectrograms](https://towardsdatascience.com/learning-from-audio-spectrograms-37df29dba98c)
#
# ![Spectogram.png](attachment:46528290-6db2-4143-901a-b065bd504edd.png)

# %% [markdown]
# ## Mel Spectogram
#
# Mel spectrograms are different from spectrograms in that they display frequencies on the mel scale, which is nonlinear. The purpose of this logarithmic transformation is to account for the fact that humans do not perceive frequencies on a linear scale. Therefore, using the mel scale can help us-- and ML algorithms-- better associate the features to human hearing.
#
# Adapted from: https://towardsdatascience.com/getting-to-know-the-mel-spectrogram-31bca3e2d9d0
#
# ![mel_spectogram.png](attachment:7f2f3a10-cf13-4638-af54-377bc1107347.png)

# %% [markdown]
# ### Mel frequency cepstral coefficients (MFCC) spectrogram
#
# Similar to spectrograms, MFCC is another way to visualize sound. It bands together frequencies according to the mel scale.
#
# ![MFCC_spectogram.png](attachment:3b79251d-4c76-4c2a-83f7-d33390fe5b6e.png)
#
#
# If you would like to learn more about Mel Spectrograms and MFCC, check out these links (as a starting point):
# * [Learning from Audio: The Mel Scale, Mel Spectrograms, and Mel Frequency Cepstral Coefficients](https://towardsdatascience.com/learning-from-audio-the-mel-scale-mel-spectrograms-and-mel-frequency-cepstral-coefficients-f5752b6324a8).
# * [Some Commonly Used Speech Feature Extraction Algorithms](https://www.intechopen.com/chapters/63970)

# %% [markdown]
# ## 1.2 Understand the DNN Model
#
# In this part of the assignment, we will be using a very small CNN for audio processing. The model is called TinyConv.
#
# Go to `src/networks.py` for the description of the model. Our TinyConv model currently consists of 7 layers:
#
#
# 1. [Reshape](https://pytorch.org/docs/stable/generated/torch.reshape.html)
# 2. [Conv2D](https://pytorch.org/docs/stable/generated/torch.nn.Conv2d.html#torch.nn.Conv2d)
# 3. [Relu](https://pytorch.org/docs/stable/generated/torch.nn.ReLU.html#torch.nn.ReLU)
# 4. [Dropout](https://pytorch.org/docs/stable/generated/torch.nn.Dropout.html#torch.nn.Dropout)
# 5. Reshape
# 6. [Fully Connected (Linear)](https://pytorch.org/docs/stable/generated/torch.nn.Linear.html#torch.nn.Linear)
# 7. [Softmax](https://pytorch.org/docs/stable/generated/torch.nn.Softmax.html#torch.nn.Softmax)
#
# We will provide a pre-trained model to you. This model will use fp32 weights and activations. You don't need to train this fp32 model. You will be quantizing this model to int4. That means a 8x reduction in overall model size. You will observe the reduction in accuracy that happens with this quantization. QAT can recover some/much of this accuracy.

# %% [markdown]
# ## 1.3 Setup

# %% [markdown]
# ### Install required packages

# %%
# Install libraries
# !pip install -q tqdm
# !pip install -q torchaudio
# Out:
# [notice] A new release of pip available: 22.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip available: 22.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Import code dependencies

# %%
# Import libraries 
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import numpy as np
import copy
import os

import sys
##### TODO TODO TODO 
# Please update the Project Location based on your directory
PROJECT_ROOT = "/scratch/megankuo/Project4/Lab4"
# Adding assignment 2 to the system path
# -- make sure this matches your lab code's root directory
sys.path.insert(0, PROJECT_ROOT)

# %%
# Import data_proc to use data processing functions
import src.data_proc as data_proc

# Import constants to use constants defined for training
from src.constants import *
from src.quant import *

# Set random seed
# Make sure the shuffling and picking is deterministic
# Note that different value of random_seed may change rate of variation in loss/accuracy during training
# Using the same random seed value every time you rerun the notebook will 
# reproduce the training and testing results  
random_seed = RANDOM_SEED
torch.manual_seed(random_seed)
torch.cuda.manual_seed(random_seed)
np.random.seed(random_seed)
# Out:
# 2025-03-27 03:25:33.275898: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model folders are created,
# PyTorch models will be saved in /scratch/megankuo/Project4/Lab4/models/torch_models,
# ONNX models will be saved in /scratch/megankuo/Project4/Lab4/models/onnx_models,
# TensorFlow Saved Models will be saved in /scratch/megankuo/Project4/Lab4/models/tf_models,
# TensorFlow Lite models will be saved in /scratch/megankuo/Project4/Lab4/models/tflite_models,
# TensorFlow Lite Micro models will be saved in /scratch/megankuo/Project4/Lab4/models/micro_models.

# %% [markdown]
# ## 1.4 Define Quantization Functions

# %% [markdown]
# #### TODO 1: Implement the `uniform_quantize` function in `src/quant.py` (6 pts)

# %%
from src.quant import uniform_quantize

# Mini test case for uniform_quantize
with torch.no_grad():
    x = torch.tensor([2, -0.5, 0., 1.])
    scale = 1
    zero = 0
    y = uniform_quantize(x, scale, zero)
    print(y)
# Out:
# tensor([2., 0., 0., 1.])

# %% [markdown]
# #### TODO 2: Implement the `SymmetricQuantFunction` forward function in `src/quant.py`  (6 pts)

# %%
from src.quant import SymmetricQuantFunction

quant_f = SymmetricQuantFunction.apply

x = torch.tensor([2, -0.5, 0., 1.])
x.requires_grad = True
bw = 2
y = quant_f(x, bw, scale, zero)
(y ** 2).sum().backward()

print(y)
print(x.grad)
# Out:
# tensor([1., -0., 0., 1.], grad_fn=<SymmetricQuantFunctionBackward>)
# tensor([2., -0., 0., 2.])

# %% [markdown]
# #### TODO 3: Implement the `AsymmetricQuantFunction` forward function in `src/quant.py`  (6 pts)

# %%
from src.quant import AsymmetricQuantFunction

quant_f = AsymmetricQuantFunction.apply
/
x = torch.tensor([2, -0.5, 0., 1.])
x.requires_grad = True
bw = 2
y = quant_f(x, bw, scale, zero)
(y ** 2).sum().backward()

print(y)
print(x.grad)
# Out:
# tensor([2., -0., 0., 1.], grad_fn=<AsymmetricQuantFunctionBackward>)
# tensor([4., -0., 0., 2.])

# %% [markdown]
# #### TODO 4: Finish the implementation of `get_quantization_params` function in `src/quant.py` (3 pts)

# %%
from src.quant import QConfig

qconfig = QConfig(quant_bits=4, is_symmetric=True)
print(qconfig.get_quantization_params(x.min(), x.max()))

qconfig = QConfig(quant_bits=4, is_symmetric=False)
print(qconfig.get_quantization_params(x.min(), x.max()))
# Out:
# (tensor(0.2857), tensor(0, dtype=torch.int32))
# (tensor(0.3571), tensor(1, dtype=torch.int32))

# %% [markdown]
# #### TODO 5: Implement the `quantize_weights_bias` function in `src/quant.py` (6 pts)

# %%
from src.quant import quantize_weights_bias, QConfig

qconfig = QConfig(quant_bits=4, is_symmetric=True)

w1 = nn.Parameter(torch.tensor([2, -0.5, 0., 1.]))
qw1 = quantize_weights_bias(w1, qconfig)
print(qw1.data)

w2 = nn.Parameter(torch.tensor([2.5, -1, 0., 1.5]))
qw2 = quantize_weights_bias(w2, qconfig)
print(qw2.data)
# Out:
# tensor([ 2.0000, -0.5714,  0.0000,  0.8571])
# tensor([ 2.5000, -1.0714,  0.0000,  1.4286])

# %% [markdown]
# #### TODO 6: Finish the implementation of `conv2d_uniform_quantized` function in `src/quant.py`  (6 pts)

# %%
import torch.nn as nn
from src.quant import QuantWrapper

layer = nn.Linear(2, 2)
layer.weight.data = torch.tensor([[0.1, 0.1], [-0.1, 0.1]]).view(2, 2).float()
layer.bias.data = torch.tensor([1, 2]).view(*layer.bias.shape).float()
x = torch.tensor([[0., 1]])
print(layer(x))

quant_layer = QuantWrapper(
    layer, 
    QConfig(quant_bits=4, is_symmetric=True), 
    QConfig(quant_bits=4, is_symmetric=True), 
    QConfig(quant_bits=4, is_symmetric=True))
print(quant_layer(x))
# Out:
# tensor([[1.1000, 2.1000]], grad_fn=<AddmmBackward0>)
# tensor([[0.1590, 0.1590]], grad_fn=<MulBackward0>)

# %% [markdown]
# ## 1.5 Prepare model for QAT (Quantization Aware Training)

# %% [markdown]
# ### Get Audio Processor, Devices, Data Loader, and Model

# %%
# Copy the dataset from "/scratch/kmhatre/CEN524/speech_commands_dataset/speech_commands_v0.02.tar.gz" 
# to your home location and extract it using the commands below. The extraction takes a significant amount of time. 
! cp -r /scratch/kmhatre/CEN524/speech_commands_dataset/speech_commands_v0.02.tar.gz .
! mkdir -p ./speech_commands
! tar -xvf speech_commands_v0.02.tar.gz -C ./speech_commands
# Out:
# cp: cannot create regular file './speech_commands_v0.02.tar.gz': Permission denied
# ./
# ./eight/
# ./eight/1b88bf70_nohash_0.wav
# ./eight/798f702a_nohash_2.wav
# ./eight/b12bef84_nohash_1.wav
# ./eight/05b2db80_nohash_1.wav
# ./eight/b66f4f93_nohash_5.wav
# ./eight/750e3e75_nohash_0.wav
# ./eight/3852fca2_nohash_0.wav
# ./eight/5ac04a92_nohash_0.wav
# ./eight/778a4a01_nohash_0.wav
# ./eight/61e50f62_nohash_0.wav
# ./eight/0cb74144_nohash_2.wav
# ./eight/17c94b23_nohash_0.wav
# ./eight/037c445a_nohash_1.wav
# ./eight/3d794813_nohash_4.wav
# ./eight/11321027_nohash_0.wav
# ./eight/06f6c194_nohash_4.wav
# ./eight/b97c9f77_nohash_1.wav
# ./eight/10467b06_nohash_1.wav
# ./eight/321aba74_nohash_0.wav
# ./eight/d3831f6a_nohash_3.wav
# ./eight/d3831f6a_nohash_4.wav
# ./eight/baf01c1f_nohash_0.wav
# ./eight/472b8045_nohash_1.wav
# ./eight/64e48f55_nohash_1.wav
# ./eight/ab46af55_nohash_2.wav
# ./eight/6969e51a_nohash_0.wav
# ./eight/48bdc11c_nohash_0.wav
# ./eight/2e75d37a_nohash_1.wav
# ./eight/cb2929ce_nohash_4.wav
# ./eight/a6285644_nohash_2.wav
# ./eight/f30285c8_nohash_2.wav
# ./eight/01b4757a_nohash_0.wav
# ./eight/ea1f888c_nohash_0.wav
# ./eight/a6285644_nohash_1.wav
# ./eight/45692b02_nohash_0.wav
# ./eight/f68160c0_nohash_3.wav
# ./eight/88120683_nohash_0.wav
# ./eight/f44f440f_nohash_2.wav
# ./eight/1ecfb537_nohash_2.wav
# ./eight/5769c5ab_nohash_4.wav
# ./eight/7ff4fc72_nohash_0.wav
# ./eight/57b68383_nohash_2.wav
# ./eight/50f55535_nohash_0.wav
# ./eight/1e02ffc5_nohash_0.wav
# ./eight/cd7f8c1b_nohash_2.wav
# ./eight/a04817c2_nohash_2.wav
# ./eight/bb05582b_nohash_2.wav
# ./eight/b8872c20_nohash_0.wav
# ./eight/d3d8fcd0_nohash_0.wav
# ./eight/4a4e28f1_nohash_3.wav
# ./eight/3102f006_nohash_3.wav
# ./eight/9587481f_nohash_0.wav
# ./eight/eb3f7d82_nohash_1.wav
# ./eight/226537ab_nohash_0.wav
# ./eight/e99d36c8_nohash_1.wav
# ./eight/85851131_nohash_0.wav
# ./eight/de89e2ca_nohash_4.wav
# ./eight/af790082_nohash_0.wav
# ./eight/f035e2ea_nohash_5.wav
# ./eight/57152045_nohash_3.wav
# ./eight/a3502f15_nohash_0.wav
# ./eight/8ff44869_nohash_1.wav
# ./eight/4def68db_nohash_2.wav
# ./eight/73f20b00_nohash_3.wav
# ./eight/5af0ca83_nohash_0.wav
# ./eight/fafe8101_nohash_0.wav
# ./eight/f06190c1_nohash_3.wav
# ./eight/9f63152b_nohash_0.wav
# ./eight/87728a88_nohash_2.wav
# ./eight/c1d39ce8_nohash_5.wav
# ./eight/42a99aec_nohash_0.wav
# ./eight/d107dc42_nohash_0.wav
# ./eight/c7dc7278_nohash_3.wav
# ./eight/78884794_nohash_1.wav
# ./eight/325a0c39_nohash_0.wav
# ./eight/735845ab_nohash_0.wav
# ./eight/fc2411fe_nohash_0.wav
# ./eight/68dd409e_nohash_0.wav
# ./eight/a13e0a74_nohash_0.wav
# ./eight/4c6944d6_nohash_7.wav
# ./eight/6aa8def4_nohash_0.wav
# ./eight/435695e3_nohash_3.wav
# ./eight/73f20b00_nohash_4.wav
# ./eight/59b98a22_nohash_2.wav
# ./eight/8dd24423_nohash_1.wav
# ./eight/9aa21fa9_nohash_2.wav
# ./eight/471a0925_nohash_4.wav
# ./eight/a6f2fd71_nohash_2.wav
# ./eight/4a4e28f1_nohash_1.wav
# ./eight/f19c1390_nohash_4.wav
# ./eight/e91d173e_nohash_1.wav
# ./eight/e9bc5cc2_nohash_1.wav
# ./eight/57152045_nohash_2.wav
# ./eight/e882abb2_nohash_3.wav
# ./eight/a1cf7fd8_nohash_0.wav
# ./eight/81a345a3_nohash_0.wav
# ./eight/b66f4f93_nohash_4.wav
# ./eight/cd911ace_nohash_1.wav
# ./eight/61ab8fbc_nohash_2.wav
# ./eight/61ab8fbc_nohash_0.wav
# ./eight/86402da1_nohash_1.wav
# ./eight/4fd4d073_nohash_0.wav
# ./eight/a8e25ebb_nohash_1.wav
# ./eight/6904f0cb_nohash_0.wav
# ./eight/964c7c9e_nohash_0.wav
# ./eight/3cfc6b3a_nohash_1.wav
# ./eight/fbb2f6cc_nohash_3.wav
# ./eight/6fca237d_nohash_1.wav
# ./eight/71e6ab20_nohash_1.wav
# ./eight/605ed0ff_nohash_1.wav
# ./eight/8aa35b0c_nohash_1.wav
# ./eight/3a69f765_nohash_0.wav
# ./eight/1f653d27_nohash_1.wav
# ./eight/56eb74ae_nohash_0.wav
# ./eight/e62056e2_nohash_0.wav
# ./eight/cce7416f_nohash_2.wav
# ./eight/b414c653_nohash_0.wav
# ./eight/229978fd_nohash_1.wav
# ./eight/30276d03_nohash_0.wav
# ./eight/434a267c_nohash_0.wav
# ./eight/1b4c9b89_nohash_0.wav
# ./eight/0474c92a_nohash_1.wav
# ./eight/ec74a8a5_nohash_0.wav
# ./eight/bbaa7946_nohash_2.wav
# ./eight/18f8afd5_nohash_3.wav
# ./eight/7195ffa6_nohash_0.wav
# ./eight/01bb6a2a_nohash_2.wav
# ./eight/3b4f8f24_nohash_1.wav
# ./eight/31d68957_nohash_0.wav
# ./eight/bd11c654_nohash_0.wav
# ./eight/7fb8d703_nohash_1.wav
# ./eight/1acc97de_nohash_2.wav
# ./eight/1b755c65_nohash_0.wav
# ./eight/c6ee87a7_nohash_3.wav
# ./eight/7ff085e1_nohash_2.wav
# ./eight/28e47b1a_nohash_3.wav
# ./eight/b0f5b16d_nohash_3.wav
# ./eight/0e6e36c9_nohash_4.wav
# ./eight/a929f9b9_nohash_4.wav
# ./eight/54aecbd5_nohash_2.wav
# ./eight/821b64cc_nohash_1.wav
# ./eight/682e1687_nohash_2.wav
# ./eight/196e84b7_nohash_0.wav
# ./eight/b87bdb22_nohash_0.wav
# ./eight/6904f0cb_nohash_2.wav
# ./eight/62f05757_nohash_0.wav
# ./eight/81dc4a94_nohash_0.wav
# ./eight/a9b574b3_nohash_0.wav
# ./eight/106a6183_nohash_0.wav
# ./eight/86f12ac0_nohash_1.wav
# ./eight/9735764a_nohash_0.wav
# ./eight/6aa8def4_nohash_2.wav
# ./eight/54aecbd5_nohash_1.wav
# ./eight/ee4a907f_nohash_0.wav
# ./eight/6d1dcca6_nohash_0.wav
# ./eight/28ce0c58_nohash_1.wav
# ./eight/15c563d7_nohash_2.wav
# ./eight/da040491_nohash_3.wav
# ./eight/4995d875_nohash_0.wav
# ./eight/8e69dc2f_nohash_0.wav
# ./eight/29229c21_nohash_3.wav
# ./eight/c4e00ee9_nohash_0.wav
# ./eight/b5552931_nohash_3.wav
# ./eight/0e5193e6_nohash_0.wav
# ./eight/c634a189_nohash_2.wav
# ./eight/72aa7259_nohash_0.wav
# ./eight/742d6431_nohash_0.wav
# ./eight/b7e9f841_nohash_1.wav
# ./eight/a1dd919f_nohash_2.wav
# ./eight/4634529e_nohash_1.wav
# ./eight/530306f5_nohash_0.wav
# ./eight/19785c4e_nohash_0.wav
# ./eight/e7bcee8a_nohash_1.wav
# ./eight/951cac20_nohash_0.wav
# ./eight/f9af823e_nohash_0.wav
# ./eight/5a98d407_nohash_1.wav
# ./eight/439c84f4_nohash_1.wav
# ./eight/924c1a04_nohash_0.wav
# ./eight/645ed69d_nohash_3.wav
# ./eight/b29f8b23_nohash_0.wav
# ./eight/3d86b69a_nohash_1.wav
# ./eight/5a5721f8_nohash_1.wav
# ./eight/54b6d355_nohash_3.wav
# ./eight/779de043_nohash_2.wav
# ./eight/c8771f88_nohash_2.wav
# ./eight/da15e796_nohash_0.wav
# ./eight/8d8d9855_nohash_0.wav
# ./eight/42a99aec_nohash_4.wav
# ./eight/3cc595de_nohash_2.wav
# ./eight/d9ae8983_nohash_0.wav
# ./eight/7257420c_nohash_3.wav
# ./eight/c518d1b1_nohash_0.wav
# ./eight/6e899c9a_nohash_0.wav
# ./eight/257251e0_nohash_0.wav
# ./eight/11860c84_nohash_1.wav
# ./eight/b0ae6326_nohash_2.wav
# ./eight/eb3f7d82_nohash_0.wav
# ./eight/18a8f03f_nohash_0.wav
# ./eight/bde0f20a_nohash_0.wav
# ./eight/7f74626f_nohash_0.wav
# ./eight/af790082_nohash_4.wav
# ./eight/513aeddf_nohash_4.wav
# ./eight/b5cf6ea8_nohash_0.wav
# ./eight/51f7a034_nohash_0.wav
# ./eight/b00c4c53_nohash_1.wav
# ./eight/f19279c4_nohash_0.wav
# ./eight/2197f41c_nohash_0.wav
# ./eight/d430b3cc_nohash_0.wav
# ./eight/08ab8082_nohash_0.wav
# ./eight/9b8a7439_nohash_4.wav
# ./eight/39833acb_nohash_2.wav
# ./eight/9d32f10a_nohash_0.wav
# ./eight/a879a2c3_nohash_2.wav
# ./eight/e6327279_nohash_2.wav
# ./eight/b544d4fd_nohash_0.wav
# ./eight/a1dd919f_nohash_1.wav
# ./eight/d5cdb23e_nohash_0.wav
# ./eight/893705bb_nohash_6.wav
# ./eight/2903efb3_nohash_1.wav
# ./eight/f5733968_nohash_1.wav
# ./eight/0d2bcf9d_nohash_2.wav
# ./eight/c948d727_nohash_2.wav
# ./eight/f9643d42_nohash_3.wav
# ./eight/6add0595_nohash_0.wav
# ./eight/876c84d6_nohash_0.wav
# ./eight/131e738d_nohash_1.wav
# ./eight/7f74626f_nohash_3.wav
# ./eight/e1469561_nohash_4.wav
# ./eight/98ea0818_nohash_0.wav
# ./eight/b29f8b23_nohash_3.wav
# ./eight/88053e92_nohash_0.wav
# ./eight/1a073312_nohash_0.wav
# ./eight/779de043_nohash_4.wav
# ./eight/0f7266cf_nohash_1.wav
# ./eight/44f68a83_nohash_0.wav
# ./eight/6d7af359_nohash_0.wav
# ./eight/0ea9c8ce_nohash_3.wav
# ./eight/f9643d42_nohash_0.wav
# ./eight/fbb2f6cc_nohash_1.wav
# ./eight/d926bb17_nohash_0.wav
# ./eight/5be23def_nohash_0.wav
# ./eight/821b64cc_nohash_2.wav
# ./eight/508e30ee_nohash_4.wav
# ./eight/d278d8ef_nohash_3.wav
# ./eight/4a1e736b_nohash_1.wav
# ./eight/0ea9c8ce_nohash_2.wav
# ./eight/2fee065a_nohash_0.wav
# ./eight/3e31dffe_nohash_0.wav
# ./eight/173ae793_nohash_1.wav
# ./eight/893705bb_nohash_2.wav
# ./eight/e0315cf6_nohash_2.wav
# ./eight/67961766_nohash_0.wav
# ./eight/676f8138_nohash_0.wav
# ./eight/88a487ce_nohash_0.wav
# ./eight/27c30960_nohash_0.wav
# ./eight/b9f46737_nohash_3.wav
# ./eight/3c4aa5ef_nohash_3.wav
# ./eight/63996b7c_nohash_1.wav
# ./eight/db9cfc88_nohash_1.wav
# ./eight/41777abb_nohash_0.wav
# ./eight/8134f43f_nohash_3.wav
# ./eight/b66f4f93_nohash_2.wav
# ./eight/0717b9f6_nohash_3.wav
# ./eight/6a497f80_nohash_0.wav
# ./eight/e0c782d5_nohash_4.wav
# ./eight/93f30cc4_nohash_0.wav
# ./eight/5b09db89_nohash_2.wav
# ./eight/a16013b7_nohash_3.wav
# ./eight/69a1a79f_nohash_4.wav
# ./eight/14c7b073_nohash_1.wav
# ./eight/3bc21161_nohash_2.wav
# ./eight/763188c4_nohash_1.wav
# ./eight/ab353673_nohash_0.wav
# ./eight/db72a474_nohash_0.wav
# ./eight/099d52ad_nohash_2.wav
# ./eight/050170cb_nohash_2.wav
# ./eight/83f9c4ab_nohash_1.wav
# ./eight/e1aa22e4_nohash_0.wav
# ./eight/8a90cf67_nohash_0.wav
# ./eight/e7ea8b76_nohash_3.wav
# ./eight/131e738d_nohash_3.wav
# ./eight/619b5164_nohash_0.wav
# ./eight/ff2b842e_nohash_1.wav
# ./eight/da27460c_nohash_3.wav
# ./eight/fd5ccd39_nohash_2.wav
# ./eight/b8897f1c_nohash_0.wav
# ./eight/333784b7_nohash_1.wav
# ./eight/5e3dde6b_nohash_4.wav
# ./eight/ab9b93e4_nohash_0.wav
# ./eight/bd76a7fd_nohash_3.wav
# ./eight/9a4d12fd_nohash_0.wav
# ./eight/d0faf7e4_nohash_0.wav
# ./eight/8eb4a1bf_nohash_3.wav
# ./eight/7846fd85_nohash_4.wav
# ./eight/513aeddf_nohash_3.wav
# ./eight/b6d11c9b_nohash_1.wav
# ./eight/51055bda_nohash_2.wav
# ./eight/a1533da4_nohash_0.wav
# ./eight/0bde966a_nohash_2.wav
# ./eight/59fe87e6_nohash_0.wav
# ./eight/9b02d503_nohash_0.wav
# ./eight/91b03183_nohash_2.wav
# ./eight/5f9cd2eb_nohash_2.wav
# ./eight/8f4c551f_nohash_0.wav
# ./eight/34d5aa5a_nohash_0.wav
# ./eight/c2dccf38_nohash_0.wav
# ./eight/14c2b13d_nohash_0.wav
# ./eight/74241b28_nohash_3.wav
# ./eight/ac7840d8_nohash_1.wav
# ./eight/e6327279_nohash_1.wav
# ./eight/a929f9b9_nohash_3.wav
# ./eight/9aa21fa9_nohash_4.wav
# ./eight/437455be_nohash_0.wav
# ./eight/bed06fac_nohash_0.wav
# ./eight/eaa83485_nohash_0.wav
# ./eight/b46e8153_nohash_0.wav
# ./eight/8ff44869_nohash_0.wav
# ./eight/bab36420_nohash_0.wav
# ./eight/92a9c5e6_nohash_1.wav
# ./eight/789e4ee7_nohash_0.wav
# ./eight/7d4beb11_nohash_0.wav
# ./eight/4e6902d0_nohash_2.wav
# ./eight/e1469561_nohash_1.wav
# ./eight/09ddc105_nohash_0.wav
# ./eight/4cee0c60_nohash_3.wav
# ./eight/38d78313_nohash_1.wav
# ./eight/de3fe344_nohash_4.wav
# ./eight/f2898d06_nohash_2.wav
# ./eight/953fe1ad_nohash_3.wav
# ./eight/beb458a4_nohash_0.wav
# ./eight/ec201020_nohash_3.wav
# ./eight/da584bc0_nohash_0.wav
# ./eight/8e05039f_nohash_0.wav
# ./eight/c256377f_nohash_0.wav
# ./eight/cc6ee39b_nohash_0.wav
# ./eight/2aca1e72_nohash_0.wav
# ./eight/f19279c4_nohash_1.wav
# ./eight/1ed0b13d_nohash_2.wav
# ./eight/bfd26d6b_nohash_1.wav
# ./eight/61e2f74f_nohash_2.wav
# ./eight/d070ea86_nohash_4.wav
# ./eight/b76f6088_nohash_4.wav
# ./eight/2cec1d47_nohash_1.wav
# ./eight/e48a80ed_nohash_0.wav
# ./eight/050170cb_nohash_3.wav
# ./eight/c1b7c224_nohash_1.wav
# ./eight/3efa7ec4_nohash_0.wav
# ./eight/a8f45bdc_nohash_1.wav
# ./eight/6c429c7b_nohash_2.wav
# ./eight/197f4153_nohash_3.wav
# ./eight/9fac5701_nohash_2.wav
# ./eight/a5b24175_nohash_1.wav
# ./eight/4b25f620_nohash_1.wav
# ./eight/23da904f_nohash_1.wav
# ./eight/37b03ab1_nohash_0.wav
# ./eight/ca4912b6_nohash_2.wav
# ./eight/2d82a556_nohash_3.wav
# ./eight/cc8b3228_nohash_2.wav
# ./eight/ed032775_nohash_2.wav
# ./eight/fcb25a78_nohash_2.wav
# ./eight/9c24bc76_nohash_0.wav
# ./eight/7c75a504_nohash_0.wav
# ./eight/a7dd45cf_nohash_1.wav
# ./eight/1c84a139_nohash_4.wav
# ./eight/bbd0bbd0_nohash_1.wav
# ./eight/9229bff9_nohash_0.wav
# ./eight/7ea032f3_nohash_3.wav
# ./eight/b63fea9e_nohash_1.wav
# ./eight/023a61ad_nohash_0.wav
# ./eight/8012c69d_nohash_1.wav
# ./eight/d7467392_nohash_0.wav
# ./eight/0f46028a_nohash_1.wav
# ./eight/122c5aa7_nohash_1.wav
# ./eight/2c393fd2_nohash_0.wav
# ./eight/b5cf6ea8_nohash_4.wav
# ./eight/365908bd_nohash_2.wav
# ./eight/627c0bec_nohash_0.wav
# ./eight/efab2cbd_nohash_1.wav
# ./eight/27c24504_nohash_1.wav
# ./eight/29dce108_nohash_4.wav
# ./eight/a929f9b9_nohash_0.wav
# ./eight/4cee0c60_nohash_4.wav
# ./eight/b843de62_nohash_0.wav
# ./eight/6af4aa07_nohash_0.wav
# ./eight/826268f8_nohash_3.wav
# ./eight/fdb5155e_nohash_1.wav
# ./eight/325a0c39_nohash_1.wav
# ./eight/2151b09a_nohash_0.wav
# ./eight/3b195250_nohash_0.wav
# ./eight/e76dd1ce_nohash_0.wav
# ./eight/1e02ffc5_nohash_1.wav
# ./eight/f35eedd7_nohash_0.wav
# ./eight/8353fea1_nohash_0.wav
# ./eight/e453d477_nohash_0.wav
# ./eight/a489191a_nohash_3.wav
# ./eight/db43cd03_nohash_0.wav
# ./eight/21832144_nohash_2.wav
# ./eight/2d82a556_nohash_0.wav
# ./eight/ef3367d9_nohash_3.wav
# ./eight/c7dc7278_nohash_0.wav
# ./eight/884ae8e1_nohash_0.wav
# ./eight/d070ea86_nohash_0.wav
# ./eight/8f4c551f_nohash_1.wav
# ./eight/7dc50b88_nohash_0.wav
# ./eight/71904de3_nohash_0.wav
# ./eight/87070229_nohash_2.wav
# ./eight/75b631ff_nohash_2.wav
# ./eight/e3e0f145_nohash_3.wav
# ./eight/07ad9b59_nohash_0.wav
# ./eight/2aca1e72_nohash_10.wav
# ./eight/8523766b_nohash_0.wav
# ./eight/f632210f_nohash_0.wav
# ./eight/f5733968_nohash_3.wav
# ./eight/1b4c9b89_nohash_3.wav
# ./eight/b63fea9e_nohash_4.wav
# ./eight/e3e0f145_nohash_0.wav
# ./eight/f42e234b_nohash_1.wav
# ./eight/8a8756a4_nohash_0.wav
# ./eight/ea0cf37f_nohash_0.wav
# ./eight/7ea032f3_nohash_1.wav
# ./eight/2a0b413e_nohash_0.wav
# ./eight/e54a0f16_nohash_1.wav
# ./eight/69a1a79f_nohash_0.wav
# ./eight/6c429c7b_nohash_1.wav
# ./eight/e57abea3_nohash_0.wav
# ./eight/e71a9381_nohash_0.wav
# ./eight/cfde27ba_nohash_0.wav
# ./eight/017c4098_nohash_1.wav
# ./eight/65d14087_nohash_0.wav
# ./eight/2f813234_nohash_0.wav
# ./eight/c08e5058_nohash_0.wav
# ./eight/616420be_nohash_2.wav
# ./eight/789e4ee7_nohash_1.wav
# ./eight/3bfd30e6_nohash_1.wav
# ./eight/135c6841_nohash_1.wav
# ./eight/bb31b82b_nohash_0.wav
# ./eight/b69002d4_nohash_0.wav
# ./eight/ffd2ba2f_nohash_3.wav
# ./eight/8910e5ef_nohash_1.wav
# ./eight/cc4f9250_nohash_2.wav
# ./eight/8769c34c_nohash_0.wav
# ./eight/6565a81d_nohash_0.wav
# ./eight/c351e611_nohash_2.wav
# ./eight/9b027ecf_nohash_0.wav
# ./eight/c1b7c224_nohash_0.wav
# ./eight/e1469561_nohash_2.wav
# ./eight/5628d7b7_nohash_0.wav
# ./eight/6727b579_nohash_1.wav
# ./eight/6bd4554d_nohash_0.wav
# ./eight/beb49c22_nohash_0.wav
# ./eight/ffd2ba2f_nohash_2.wav
# ./eight/aef8dcf5_nohash_0.wav
# ./eight/656e8bb3_nohash_0.wav
# ./eight/f5341341_nohash_3.wav
# ./eight/c79159aa_nohash_1.wav
# ./eight/5b1db3ee_nohash_0.wav
# ./eight/8281a2a8_nohash_1.wav
# ./eight/8b25410a_nohash_0.wav
# ./eight/c1d39ce8_nohash_0.wav
# ./eight/f822b9bf_nohash_2.wav
# ./eight/89d6d11e_nohash_0.wav
# ./eight/e9e07a2d_nohash_0.wav
# ./eight/60472d26_nohash_0.wav
# ./eight/435f9f9e_nohash_1.wav
# ./eight/1b18600d_nohash_1.wav
# ./eight/229978fd_nohash_2.wav
# ./eight/7117fb6d_nohash_0.wav
# ./eight/85834399_nohash_0.wav
# ./eight/b308773d_nohash_1.wav
# ./eight/2aca1e72_nohash_8.wav
# ./eight/6c968bd9_nohash_0.wav
# ./eight/a8f45bdc_nohash_0.wav
# ./eight/db24628d_nohash_1.wav
# ./eight/e48a80ed_nohash_1.wav
# ./eight/59c3a7f2_nohash_0.wav
# ./eight/bfa63751_nohash_0.wav
# ./eight/84999496_nohash_0.wav
# ./eight/229978fd_nohash_4.wav
# ./eight/9ff2d2f4_nohash_3.wav
# ./eight/fac7deca_nohash_0.wav
# ./eight/da584bc0_nohash_1.wav
# ./eight/890cc926_nohash_1.wav
# ./eight/eb3f7d82_nohash_4.wav
# ./eight/0f7266cf_nohash_2.wav
# ./eight/bcf614a2_nohash_1.wav
# ./eight/ceaadb24_nohash_0.wav
# ./eight/c9b653a0_nohash_0.wav
# ./eight/f4cae173_nohash_1.wav
# ./eight/85c5eaa0_nohash_1.wav
# ./eight/d952a17e_nohash_0.wav
# ./eight/f0522ff4_nohash_1.wav
# ./eight/e49428d9_nohash_0.wav
# ./eight/2d82a556_nohash_2.wav
# ./eight/837f7378_nohash_0.wav
# ./eight/6a700f9d_nohash_1.wav
# ./eight/0a196374_nohash_0.wav
# ./eight/d264f7b6_nohash_1.wav
# ./eight/c9b653a0_nohash_4.wav
# ./eight/2f666bb2_nohash_0.wav
# ./eight/d4dddb92_nohash_0.wav
# ./eight/1ed0b13d_nohash_0.wav
# ./eight/f736ab63_nohash_2.wav
# ./eight/499be02e_nohash_4.wav
# ./eight/f2e9b610_nohash_4.wav
# ./eight/964e8cfd_nohash_0.wav
# ./eight/0b09edd3_nohash_1.wav
# ./eight/cc3b5b62_nohash_2.wav
# ./eight/7f9eb952_nohash_1.wav
# ./eight/c1d39ce8_nohash_6.wav
# ./eight/890cc926_nohash_4.wav
# ./eight/64220627_nohash_3.wav
# ./eight/70a00e98_nohash_2.wav
# ./eight/de89e2ca_nohash_1.wav
# ./eight/6fb3d5a7_nohash_2.wav
# ./eight/a04817c2_nohash_4.wav
# ./eight/ab9b93e4_nohash_2.wav
# ./eight/7c75a504_nohash_1.wav
# ./eight/29fb33da_nohash_0.wav
# ./eight/3bfd30e6_nohash_3.wav
# ./eight/eaa83485_nohash_2.wav
# ./eight/3d794813_nohash_2.wav
# ./eight/aa80f517_nohash_4.wav
# ./eight/fa70c187_nohash_1.wav
# ./eight/5e3dde6b_nohash_0.wav
# ./eight/df1d5024_nohash_0.wav
# ./eight/e20be42a_nohash_0.wav
# ./eight/f736ab63_nohash_3.wav
# ./eight/f2f0d244_nohash_2.wav
# ./eight/da27460c_nohash_2.wav
# ./eight/fb7c9b3b_nohash_0.wav
# ./eight/50ed8a7b_nohash_1.wav
# ./eight/beb458a4_nohash_1.wav
# ./eight/888a0c49_nohash_4.wav
# ./eight/91cdef62_nohash_1.wav
# ./eight/88f8a99c_nohash_0.wav
# ./eight/ce0cb033_nohash_3.wav
# ./eight/4c3cddb8_nohash_3.wav
# ./eight/42c467d0_nohash_0.wav
# ./eight/54b6d355_nohash_1.wav
# ./eight/113b3fbc_nohash_0.wav
# ./eight/ea0cf37f_nohash_2.wav
# ./eight/c22d3f18_nohash_0.wav
# ./eight/2fa39636_nohash_0.wav
# ./eight/2bdbe5f7_nohash_3.wav
# ./eight/10627519_nohash_0.wav
# ./eight/ec989d6d_nohash_0.wav
# ./eight/617aeb6c_nohash_4.wav
# ./eight/d278d8ef_nohash_1.wav
# ./eight/c692524d_nohash_0.wav
# ./eight/264f471d_nohash_3.wav
# ./eight/4c6167ca_nohash_3.wav
# ./eight/adebe223_nohash_0.wav
# ./eight/3ec05c3d_nohash_0.wav
# ./eight/ee1d8d49_nohash_2.wav
# ./eight/acfd5b5e_nohash_2.wav
# ./eight/8c7f81df_nohash_1.wav
# ./eight/2fcb6397_nohash_2.wav
# ./eight/5c39594f_nohash_0.wav
# ./eight/caf9fceb_nohash_0.wav
# ./eight/651d108f_nohash_0.wav
# ./eight/4995d875_nohash_4.wav
# ./eight/1a4259c3_nohash_0.wav
# ./eight/264f471d_nohash_4.wav
# ./eight/651d108f_nohash_1.wav
# ./eight/d98dd124_nohash_2.wav
# ./eight/a8ee11c7_nohash_0.wav
# ./eight/afe0b87d_nohash_0.wav
# ./eight/af30314d_nohash_0.wav
# ./eight/c0e0f834_nohash_0.wav
# ./eight/c50225fa_nohash_0.wav
# ./eight/2b715941_nohash_0.wav
# ./eight/3d794813_nohash_3.wav
# ./eight/f0522ff4_nohash_2.wav
# ./eight/bbbf4fbd_nohash_0.wav
# ./eight/8b25410a_nohash_4.wav
# ./eight/80c45ed6_nohash_1.wav
# ./eight/57152045_nohash_1.wav
# ./eight/c0c701f1_nohash_1.wav
# ./eight/e49428d9_nohash_2.wav
# ./eight/43f57297_nohash_0.wav
# ./eight/d5dd88da_nohash_1.wav
# ./eight/2cec1d47_nohash_2.wav
# ./eight/333784b7_nohash_4.wav
# ./eight/86402da1_nohash_0.wav
# ./eight/08ab231c_nohash_1.wav
# ./eight/14c7b073_nohash_2.wav
# ./eight/21832144_nohash_3.wav
# ./eight/c120e80e_nohash_3.wav
# ./eight/5f5eef60_nohash_0.wav
# ./eight/cce7416f_nohash_9.wav
# ./eight/5f9cd2eb_nohash_4.wav
# ./eight/f01a0d63_nohash_4.wav
# ./eight/a591c2ea_nohash_0.wav
# ./eight/0ff728b5_nohash_2.wav
# ./eight/3c257192_nohash_1.wav
# ./eight/4407ba92_nohash_0.wav
# ./eight/773e26f7_nohash_3.wav
# ./eight/5769c5ab_nohash_0.wav
# ./eight/29229c21_nohash_0.wav
# ./eight/18e910f4_nohash_1.wav
# ./eight/5b09db89_nohash_3.wav
# ./eight/bab36420_nohash_2.wav
# ./eight/acfd5b5e_nohash_1.wav
# ./eight/f3957e23_nohash_0.wav
# ./eight/65d844fc_nohash_0.wav
# ./eight/4e6902d0_nohash_1.wav
# ./eight/1851e33b_nohash_0.wav
# ./eight/638548d5_nohash_1.wav
# ./eight/42f81601_nohash_1.wav
# ./eight/fa52ddf6_nohash_3.wav
# ./eight/3b3d2f59_nohash_4.wav
# ./eight/ab9b93e4_nohash_1.wav
# ./eight/bbaa7946_nohash_0.wav
# ./eight/1fe4c891_nohash_0.wav
# ./eight/1df99a8a_nohash_0.wav
# ./eight/38d78313_nohash_3.wav
# ./eight/ab00c4b2_nohash_1.wav
# ./eight/15dd287d_nohash_3.wav
# ./eight/78884794_nohash_0.wav
# ./eight/68effe85_nohash_1.wav
# ./eight/9e92ef0c_nohash_3.wav
# ./eight/cb62dbf1_nohash_2.wav
# ./eight/35c8fa78_nohash_2.wav
# ./eight/dca2797e_nohash_0.wav
# ./eight/f01a0d63_nohash_1.wav
# ./eight/a6f2fd71_nohash_0.wav
# ./eight/333d7ddb_nohash_1.wav
# ./eight/54aecbd5_nohash_0.wav
# ./eight/964e8cfd_nohash_4.wav
# ./eight/a2cc5444_nohash_1.wav
# ./eight/87c62767_nohash_0.wav
# ./eight/4c432947_nohash_0.wav
# ./eight/9d050657_nohash_1.wav
# ./eight/ac9dee0e_nohash_2.wav
# ./eight/0f2442b6_nohash_0.wav
# ./eight/5a0bc987_nohash_0.wav
# ./eight/ccfd721c_nohash_0.wav
# ./eight/837a0f64_nohash_4.wav
# ./eight/4a1e736b_nohash_2.wav
# ./eight/4c6167ca_nohash_5.wav
# ./eight/b31ad508_nohash_0.wav
# ./eight/b3bdded5_nohash_0.wav
# ./eight/64df20d8_nohash_0.wav
# ./eight/f953e1af_nohash_1.wav
# ./eight/72d75d96_nohash_1.wav
# ./eight/d1d3e64d_nohash_1.wav
# ./eight/0d90d8e1_nohash_3.wav
# ./eight/cd671b5f_nohash_2.wav
# ./eight/8a90cf67_nohash_2.wav
# ./eight/f852895b_nohash_0.wav
# ./eight/b66f4f93_nohash_7.wav
# ./eight/b71ebf79_nohash_0.wav
# ./eight/97addd88_nohash_0.wav
# ./eight/9e92ef0c_nohash_1.wav
# ./eight/b8874962_nohash_1.wav
# ./eight/15c563d7_nohash_0.wav
# ./eight/96d8bb6f_nohash_0.wav
# ./eight/8012c69d_nohash_0.wav
# ./eight/e882abb2_nohash_4.wav
# ./eight/518588b6_nohash_0.wav
# ./eight/e91d173e_nohash_2.wav
# ./eight/dae01802_nohash_1.wav
# ./eight/7c83c5f6_nohash_0.wav
# ./eight/ca4d5368_nohash_3.wav
# ./eight/0cb74144_nohash_0.wav
# ./eight/f736ab63_nohash_0.wav
# ./eight/b3849d6e_nohash_0.wav
# ./eight/f7b43563_nohash_1.wav
# ./eight/ccb1266b_nohash_2.wav
# ./eight/31db232b_nohash_1.wav
# ./eight/616420be_nohash_3.wav
# ./eight/fb727898_nohash_0.wav
# ./eight/439c84f4_nohash_0.wav
# ./eight/0f46028a_nohash_0.wav
# ./eight/fc94edb0_nohash_0.wav
# ./eight/d9aa8c90_nohash_2.wav
# ./eight/a16013b7_nohash_0.wav
# ./eight/2dce72b3_nohash_0.wav
# ./eight/e9abfe31_nohash_2.wav
# ./eight/b7a0754f_nohash_2.wav
# ./eight/0616de09_nohash_1.wav
# ./eight/2da58b32_nohash_3.wav
# ./eight/3847619e_nohash_1.wav
# ./eight/5165cf0a_nohash_0.wav
# ./eight/6b889021_nohash_0.wav
# ./eight/063d48cf_nohash_0.wav
# ./eight/9f869f70_nohash_0.wav
# ./eight/c98bbbd3_nohash_1.wav
# ./eight/07de53d3_nohash_0.wav
# ./eight/533c6564_nohash_0.wav
# ./eight/b7e9f841_nohash_0.wav
# ./eight/638685f2_nohash_0.wav
# ./eight/baeac2ba_nohash_0.wav
# ./eight/be7fa0a3_nohash_2.wav
# ./eight/3fb8c268_nohash_0.wav
# ./eight/2748cce7_nohash_3.wav
# ./eight/51055bda_nohash_0.wav
# ./eight/fcb25a78_nohash_0.wav
# ./eight/cce7416f_nohash_12.wav
# ./eight/aa80f517_nohash_2.wav
# ./eight/3b195250_nohash_1.wav
# ./eight/7bf801d1_nohash_0.wav
# ./eight/9a69672b_nohash_3.wav
# ./eight/1df99a8a_nohash_1.wav
# ./eight/e0c782d5_nohash_3.wav
# ./eight/a929f9b9_nohash_1.wav
# ./eight/1a892463_nohash_2.wav
# ./eight/1678e6f1_nohash_0.wav
# ./eight/b6ebe225_nohash_1.wav
# ./eight/e41a903b_nohash_1.wav
# ./eight/a7200079_nohash_1.wav
# ./eight/9ff2d2f4_nohash_1.wav
# ./eight/283d7a53_nohash_1.wav
# ./eight/893705bb_nohash_12.wav
# ./eight/15c563d7_nohash_3.wav
# ./eight/798f702a_nohash_1.wav
# ./eight/00b01445_nohash_0.wav
# ./eight/513aeddf_nohash_1.wav
# ./eight/7b2e879e_nohash_1.wav
# ./eight/0f2442b6_nohash_1.wav
# ./eight/b19f7f5f_nohash_0.wav
# ./eight/ff4ed4f3_nohash_1.wav
# ./eight/113b3fbc_nohash_4.wav
# ./eight/0b77ee66_nohash_0.wav
# ./eight/da040491_nohash_0.wav
# ./eight/857366dd_nohash_0.wav
# ./eight/1b4c9b89_nohash_2.wav
# ./eight/2335770e_nohash_0.wav
# ./eight/e4be0cf6_nohash_2.wav
# ./eight/8134f43f_nohash_1.wav
# ./eight/e53139ad_nohash_0.wav
# ./eight/18e910f4_nohash_2.wav
# ./eight/f1d36c53_nohash_0.wav
# ./eight/798f702a_nohash_0.wav
# ./eight/f575faf3_nohash_1.wav
# ./eight/e882abb2_nohash_1.wav
# ./eight/64220627_nohash_2.wav
# ./eight/5f8e50a0_nohash_0.wav
# ./eight/bbaa7946_nohash_1.wav
# ./eight/8c7c9168_nohash_0.wav
# ./eight/74551073_nohash_0.wav
# ./eight/31f01a8d_nohash_1.wav
# ./eight/fc2411fe_nohash_2.wav
# ./eight/63f7a489_nohash_4.wav
# ./eight/96105282_nohash_0.wav
# ./eight/c9b5ff26_nohash_3.wav
# ./eight/78622c2b_nohash_2.wav
# ./eight/f550b7dc_nohash_0.wav
# ./eight/20fd451f_nohash_2.wav
# ./eight/31fd5cf5_nohash_1.wav
# ./eight/adec6a94_nohash_0.wav
# ./eight/b83c1acf_nohash_0.wav
# ./eight/97f4c236_nohash_0.wav
# ./eight/2197f41c_nohash_1.wav
# ./eight/91b03183_nohash_3.wav
# ./eight/82305c3a_nohash_2.wav
# ./eight/ea1f888c_nohash_1.wav
# ./eight/56cd307a_nohash_1.wav
# ./eight/94de6a6a_nohash_4.wav
# ./eight/25132942_nohash_1.wav
# ./eight/f06190c1_nohash_1.wav
# ./eight/97ae8b25_nohash_0.wav
# ./eight/a16b3102_nohash_0.wav
# ./eight/999823db_nohash_0.wav
# ./eight/b69002d4_nohash_4.wav
# ./eight/bd11c654_nohash_1.wav
# ./eight/ca4d5368_nohash_0.wav
# ./eight/cce7416f_nohash_5.wav
# ./eight/324210dd_nohash_4.wav
# ./eight/b4ea0d9a_nohash_1.wav
# ./eight/b26343e9_nohash_0.wav
# ./eight/ddedba85_nohash_0.wav
# ./eight/07089da9_nohash_3.wav
# ./eight/4c6944d6_nohash_1.wav
# ./eight/3d6bee47_nohash_0.wav
# ./eight/837a0f64_nohash_0.wav
# ./eight/bb6d4301_nohash_0.wav
# ./eight/e7d0eb3f_nohash_0.wav
# ./eight/bd76a7fd_nohash_1.wav
# ./eight/f45fcf9a_nohash_0.wav
# ./eight/cce7416f_nohash_10.wav
# ./eight/afabfa0e_nohash_0.wav
# ./eight/d37e4bf1_nohash_0.wav
# ./eight/e7d0eb3f_nohash_2.wav
# ./eight/6fb3d5a7_nohash_3.wav
# ./eight/dfb6450b_nohash_0.wav
# ./eight/12529547_nohash_0.wav
# ./eight/c4cfbe43_nohash_0.wav
# ./eight/d78858d9_nohash_0.wav
# ./eight/b4bef564_nohash_0.wav
# ./eight/d21fd169_nohash_2.wav
# ./eight/3ce4910e_nohash_2.wav
# ./eight/5170b77f_nohash_2.wav
# ./eight/5ebc1cda_nohash_4.wav
# ./eight/377e916b_nohash_0.wav
# ./eight/c22ebf46_nohash_2.wav
# ./eight/bcf614a2_nohash_4.wav
# ./eight/eb0676ec_nohash_3.wav
# ./eight/826268f8_nohash_2.wav
# ./eight/8ea22de7_nohash_0.wav
# ./eight/8f4c551f_nohash_2.wav
# ./eight/d278d8ef_nohash_0.wav
# ./eight/c7b4049e_nohash_0.wav
# ./eight/042a8dde_nohash_3.wav
# ./eight/6794a793_nohash_0.wav
# ./eight/563aa4e6_nohash_3.wav
# ./eight/257251e0_nohash_1.wav
# ./eight/80c45ed6_nohash_0.wav
# ./eight/cce7416f_nohash_6.wav
# ./eight/df6bd83f_nohash_1.wav
# ./eight/3d53244b_nohash_3.wav
# ./eight/d394ef8e_nohash_2.wav
# ./eight/4c6944d6_nohash_2.wav
# ./eight/62ccd358_nohash_0.wav
# ./eight/893705bb_nohash_9.wav
# ./eight/5f1b1051_nohash_0.wav
# ./eight/8eb4a1bf_nohash_0.wav
# ./eight/d394ef8e_nohash_1.wav
# ./eight/1e9e6bdd_nohash_4.wav
# ./eight/845f8553_nohash_3.wav
# ./eight/4fd1443e_nohash_2.wav
# ./eight/22cb56b3_nohash_0.wav
# ./eight/4c6167ca_nohash_8.wav
# ./eight/87728a88_nohash_1.wav
# ./eight/131e738d_nohash_0.wav
# ./eight/94de6a6a_nohash_1.wav
# ./eight/be7fa0a3_nohash_0.wav
# ./eight/a5609cce_nohash_0.wav
# ./eight/173ce2be_nohash_0.wav
# ./eight/5188de0d_nohash_0.wav
# ./eight/2e30f9a5_nohash_0.wav
# ./eight/87070229_nohash_0.wav
# ./eight/c351e611_nohash_0.wav
# ./eight/5ebc1cda_nohash_2.wav
# ./eight/2a1f4853_nohash_0.wav
# ./eight/ed3c2d05_nohash_0.wav
# ./eight/b2ae3928_nohash_4.wav
# ./eight/7c1d8533_nohash_3.wav
# ./eight/893705bb_nohash_10.wav
# ./eight/ddedba85_nohash_7.wav
# ./eight/a6f2fd71_nohash_3.wav
# ./eight/82305c3a_nohash_1.wav
# ./eight/3efef882_nohash_1.wav
# ./eight/e1936ce8_nohash_0.wav
# ./eight/a95dbfd4_nohash_0.wav
# ./eight/f7b43563_nohash_0.wav
# ./eight/499be02e_nohash_2.wav
# ./eight/ad63d93c_nohash_3.wav
# ./eight/7c1d8533_nohash_2.wav
# ./eight/85851131_nohash_2.wav
# ./eight/b5552931_nohash_2.wav
# ./eight/3cfc6b3a_nohash_4.wav
# ./eight/89f3ab7d_nohash_0.wav
# ./eight/e8d562ca_nohash_0.wav
# ./eight/5c39594f_nohash_3.wav
# ./eight/f575faf3_nohash_3.wav
# ./eight/28ce0c58_nohash_0.wav
# ./eight/9229bff9_nohash_1.wav
# ./eight/6ace4fe1_nohash_4.wav
# ./eight/c7f9ffb5_nohash_0.wav
# ./eight/5769c5ab_nohash_3.wav
# ./eight/616420be_nohash_0.wav
# ./eight/7ea032f3_nohash_4.wav
# ./eight/a709ddd3_nohash_0.wav
# ./eight/f19c1390_nohash_1.wav
# ./eight/a05a90c1_nohash_2.wav
# ./eight/3b3d2f59_nohash_1.wav
# ./eight/be7a5b2d_nohash_0.wav
# ./eight/cba7f985_nohash_0.wav
# ./eight/22296dbe_nohash_0.wav
# ./eight/300384f0_nohash_0.wav
# ./eight/042a8dde_nohash_0.wav
# ./eight/9190045a_nohash_1.wav
# ./eight/4c6167ca_nohash_1.wav
# ./eight/9efe5140_nohash_1.wav
# ./eight/ace072ba_nohash_1.wav
# ./eight/91942e89_nohash_0.wav
# ./eight/f2898d06_nohash_1.wav
# ./eight/a489191a_nohash_1.wav
# ./eight/2bdbe5f7_nohash_2.wav
# ./eight/5170b77f_nohash_1.wav
# ./eight/3a3ee7ed_nohash_1.wav
# ./eight/fd5ccd39_nohash_4.wav
# ./eight/42beb5eb_nohash_2.wav
# ./eight/29dce108_nohash_2.wav
# ./eight/772db621_nohash_0.wav
# ./eight/57152045_nohash_5.wav
# ./eight/9448c397_nohash_1.wav
# ./eight/c9b5ff26_nohash_1.wav
# ./eight/b5552931_nohash_4.wav
# ./eight/31f01a8d_nohash_2.wav
# ./eight/97e0c576_nohash_0.wav
# ./eight/0132a06d_nohash_2.wav
# ./eight/f6581345_nohash_0.wav
# ./eight/51f7a034_nohash_3.wav
# ./eight/893705bb_nohash_0.wav
# ./eight/18e910f4_nohash_0.wav
# ./eight/d9aa8c90_nohash_0.wav
# ./eight/bb6d4301_nohash_1.wav
# ./eight/902258bb_nohash_0.wav
# ./eight/bf5d409d_nohash_0.wav
# ./eight/856eb138_nohash_0.wav
# ./eight/c38720cb_nohash_2.wav
# ./eight/06076b6b_nohash_0.wav
# ./eight/f5733968_nohash_2.wav
# ./eight/de89e2ca_nohash_3.wav
# ./eight/bb05582b_nohash_0.wav
# ./eight/aba19127_nohash_0.wav
# ./eight/61482e52_nohash_0.wav
# ./eight/888a0c49_nohash_3.wav
# ./eight/a1dd919f_nohash_0.wav
# ./eight/cd7f8c1b_nohash_1.wav
# ./eight/96a48d28_nohash_4.wav
# ./eight/21e8c417_nohash_0.wav
# ./eight/8ca3b1db_nohash_1.wav
# ./eight/72242187_nohash_0.wav
# ./eight/b49caed3_nohash_1.wav
# ./eight/e2b7d6d6_nohash_1.wav
# ./eight/475b61f1_nohash_0.wav
# ./eight/c22ebf46_nohash_4.wav
# ./eight/171edea9_nohash_1.wav
# ./eight/234d6a48_nohash_0.wav
# ./eight/20fd451f_nohash_1.wav
# ./eight/0943c746_nohash_0.wav
# ./eight/dc75148d_nohash_0.wav
# ./eight/d37e4bf1_nohash_2.wav
# ./eight/ad63d93c_nohash_2.wav
# ./eight/3402e488_nohash_0.wav
# ./eight/0132a06d_nohash_0.wav
# ./eight/0e6e36c9_nohash_2.wav
# ./eight/2510c044_nohash_0.wav
# ./eight/f0659908_nohash_1.wav
# ./eight/de3fe344_nohash_1.wav
# ./eight/42f81601_nohash_0.wav
# ./eight/063d48cf_nohash_2.wav
# ./eight/324210dd_nohash_3.wav
# ./eight/784e281a_nohash_0.wav
# ./eight/4c6167ca_nohash_6.wav
# ./eight/eeaf97c3_nohash_2.wav
# ./eight/4c6167ca_nohash_4.wav
# ./eight/e10e2cbb_nohash_0.wav
# ./eight/b76f6088_nohash_3.wav
# ./eight/acb9db68_nohash_0.wav
# ./eight/637c702a_nohash_0.wav
# ./eight/94de6a6a_nohash_0.wav
# ./eight/86478fab_nohash_1.wav
# ./eight/a7216980_nohash_4.wav
# ./eight/45adf84a_nohash_0.wav
# ./eight/a1e71565_nohash_3.wav
# ./eight/bbf38549_nohash_0.wav
# ./eight/a489191a_nohash_0.wav
# ./eight/270bfa52_nohash_2.wav
# ./eight/2748cce7_nohash_2.wav
# ./eight/cc3b5b62_nohash_3.wav
# ./eight/d9aa8c90_nohash_3.wav
# ./eight/5165cf0a_nohash_1.wav
# ./eight/ddedba85_nohash_6.wav
# ./eight/66cff190_nohash_0.wav
# ./eight/b91b718c_nohash_0.wav
# ./eight/42f81601_nohash_2.wav
# ./eight/f2e59fea_nohash_1.wav
# ./eight/adebe223_nohash_2.wav
# ./eight/8b25410a_nohash_3.wav
# ./eight/3cc595de_nohash_3.wav
# ./eight/eb0676ec_nohash_1.wav
# ./eight/b49caed3_nohash_3.wav
# ./eight/8769c34c_nohash_3.wav
# ./eight/3c257192_nohash_3.wav
# ./eight/cb72dfb6_nohash_3.wav
# ./eight/f19c1390_nohash_3.wav
# ./eight/4abefdf5_nohash_0.wav
# ./eight/f68160c0_nohash_2.wav
# ./eight/5170b77f_nohash_0.wav
# ./eight/f01a0d63_nohash_0.wav
# ./eight/0a2b400e_nohash_1.wav
# ./eight/0a196374_nohash_2.wav
# ./eight/f0ac2522_nohash_1.wav
# ./eight/c120e80e_nohash_0.wav
# ./eight/4f8ef132_nohash_0.wav
# ./eight/e2b7d6d6_nohash_3.wav
# ./eight/5a98d407_nohash_2.wav
# ./eight/50928b05_nohash_0.wav
# ./eight/845f8553_nohash_2.wav
# ./eight/eeaf97c3_nohash_0.wav
# ./eight/4845bb10_nohash_0.wav
# ./eight/413bcfe1_nohash_0.wav
# ./eight/b4aa9fef_nohash_4.wav
# ./eight/52bfbce8_nohash_0.wav
# ./eight/95299b6c_nohash_1.wav
# ./eight/c4e00ee9_nohash_2.wav
# ./eight/09ddc105_nohash_1.wav
# ./eight/9aa21fa9_nohash_0.wav
# ./eight/ef3367d9_nohash_0.wav
# ./eight/589bce2c_nohash_0.wav
# ./eight/ec989d6d_nohash_2.wav
# ./eight/94de6a6a_nohash_3.wav
# ./eight/0e6e36c9_nohash_1.wav
# ./eight/9be15e93_nohash_2.wav
# ./eight/c0445658_nohash_0.wav
# ./eight/a8e25ebb_nohash_0.wav
# ./eight/3291330e_nohash_1.wav
# ./eight/d9b8fab2_nohash_0.wav
# ./eight/8a744054_nohash_0.wav
# ./eight/b8b8cb52_nohash_0.wav
# ./eight/a3fc7884_nohash_0.wav
# ./eight/54aecbd5_nohash_3.wav
# ./eight/b17f5ba0_nohash_1.wav
# ./eight/ddedba85_nohash_13.wav
# ./eight/1dce06e8_nohash_0.wav
# ./eight/017c4098_nohash_2.wav
# ./eight/3847619e_nohash_2.wav
# ./eight/57152045_nohash_0.wav
# ./eight/9f4098cb_nohash_1.wav
# ./eight/f2e59fea_nohash_2.wav
# ./eight/b25b6065_nohash_0.wav
# ./eight/3d53244b_nohash_0.wav
# ./eight/cb2929ce_nohash_5.wav
# ./eight/9b6c08ba_nohash_0.wav
# ./eight/f2dd248e_nohash_0.wav
# ./eight/c013fe4d_nohash_0.wav
# ./eight/ac9dee0e_nohash_3.wav
# ./eight/7e7ca854_nohash_2.wav
# ./eight/0132a06d_nohash_1.wav
# ./eight/c120e80e_nohash_4.wav
# ./eight/0132a06d_nohash_3.wav
# ./eight/173ae793_nohash_2.wav
# ./eight/a6d586b7_nohash_3.wav
# ./eight/d5dd88da_nohash_0.wav
# ./eight/fda46b78_nohash_0.wav
# ./eight/24b82192_nohash_0.wav
# ./eight/712e4d58_nohash_1.wav
# ./eight/686d030b_nohash_0.wav
# ./eight/03431e13_nohash_0.wav
# ./eight/8523766b_nohash_1.wav
# ./eight/893705bb_nohash_13.wav
# ./eight/e9323bd9_nohash_1.wav
# ./eight/189cbabe_nohash_4.wav
# ./eight/1930353c_nohash_0.wav
# ./eight/31583d30_nohash_2.wav
# ./eight/3903b558_nohash_0.wav
# ./eight/f638a812_nohash_0.wav
# ./eight/042a8dde_nohash_1.wav
# ./eight/28ce0c58_nohash_3.wav
# ./eight/fa57ab3b_nohash_4.wav
# ./eight/18a8f03f_nohash_1.wav
# ./eight/25132942_nohash_2.wav
# ./eight/be7fa0a3_nohash_1.wav
# ./eight/3b4f8f24_nohash_2.wav
# ./eight/15574821_nohash_2.wav
# ./eight/e99d36c8_nohash_0.wav
# ./eight/6e2ef3d5_nohash_0.wav
# ./eight/36050ef3_nohash_2.wav
# ./eight/ca4d5368_nohash_1.wav
# ./eight/099d52ad_nohash_0.wav
# ./eight/57b68383_nohash_0.wav
# ./eight/578d3efb_nohash_0.wav
# ./eight/5ebc1cda_nohash_1.wav
# ./eight/3a70ab7f_nohash_0.wav
# ./eight/64e48f55_nohash_0.wav
# ./eight/bd8412df_nohash_0.wav
# ./eight/84bf12ff_nohash_0.wav
# ./eight/64df20d8_nohash_3.wav
# ./eight/efbc3952_nohash_0.wav
# ./eight/7fd25f7c_nohash_0.wav
# ./eight/3589bc72_nohash_4.wav
# ./eight/ff2b842e_nohash_2.wav
# ./eight/6727b579_nohash_0.wav
# ./eight/9dc1889e_nohash_1.wav
# ./eight/eaa83485_nohash_1.wav
# ./eight/15f04ff8_nohash_0.wav
# ./eight/8281a2a8_nohash_2.wav
# ./eight/e76dd1ce_nohash_1.wav
# ./eight/5ff3f9a1_nohash_0.wav
# ./eight/c7aaad67_nohash_0.wav
# ./eight/3ec05c3d_nohash_1.wav
# ./eight/f2f0d244_nohash_3.wav
# ./eight/f292725f_nohash_0.wav
# ./eight/435695e3_nohash_0.wav
# ./eight/01bcfc0c_nohash_1.wav
# ./eight/f2f0d244_nohash_0.wav
# ./eight/171edea9_nohash_2.wav
# ./eight/61482e52_nohash_1.wav
# ./eight/0ea9c8ce_nohash_4.wav
# ./eight/978240e1_nohash_3.wav
# ./eight/f953e1af_nohash_2.wav
# ./eight/b63fea9e_nohash_3.wav
# ./eight/25e95412_nohash_3.wav
# ./eight/bab36420_nohash_1.wav
# ./eight/2fee065a_nohash_1.wav
# ./eight/a5a16097_nohash_0.wav
# ./eight/3a3ee7ed_nohash_4.wav
# ./eight/4b3a7ad5_nohash_0.wav
# ./eight/e7ebf59c_nohash_0.wav
# ./eight/617aeb6c_nohash_1.wav
# ./eight/7c1d8533_nohash_0.wav
# ./eight/fbb56351_nohash_1.wav
# ./eight/8b25410a_nohash_1.wav
# ./eight/1a994c9f_nohash_2.wav
# ./eight/439c84f4_nohash_2.wav
# ./eight/eeaf97c3_nohash_3.wav
# ./eight/73f20b00_nohash_2.wav
# ./eight/7213ed54_nohash_2.wav
# ./eight/a4e8a997_nohash_1.wav
# ./eight/8769c34c_nohash_1.wav
# ./eight/3f45a0cf_nohash_2.wav
# ./eight/efa16ffd_nohash_0.wav
# ./eight/fc3ba625_nohash_3.wav
# ./eight/cd68e997_nohash_0.wav
# ./eight/e3e0f145_nohash_4.wav
# ./eight/5b26c81b_nohash_0.wav
# ./eight/2039b9c1_nohash_0.wav
# ./eight/a13e0a74_nohash_1.wav
# ./eight/87d5e978_nohash_1.wav
# ./eight/da040491_nohash_2.wav
# ./eight/7213ed54_nohash_0.wav
# ./eight/aa48c94a_nohash_1.wav
# ./eight/89947bd7_nohash_2.wav
# ./eight/551e42e8_nohash_0.wav
# ./eight/617aeb6c_nohash_0.wav
# ./eight/bfaf2000_nohash_2.wav
# ./eight/a1c63f25_nohash_0.wav
# ./eight/d85270c1_nohash_0.wav
# ./eight/37bd115d_nohash_0.wav
# ./eight/e7ea8b76_nohash_0.wav
# ./eight/4fd1443e_nohash_4.wav
# ./eight/eee5e541_nohash_0.wav
# ./eight/471a0925_nohash_3.wav
# ./eight/884ae8e1_nohash_1.wav
# ./eight/fb7eb481_nohash_0.wav
# ./eight/815f0f03_nohash_0.wav
# ./eight/a04817c2_nohash_3.wav
# ./eight/aca15398_nohash_0.wav
# ./eight/d264f7b6_nohash_2.wav
# ./eight/0e17f595_nohash_0.wav
# ./eight/31fd5cf5_nohash_0.wav
# ./eight/3a3ee7ed_nohash_3.wav
# ./eight/36050ef3_nohash_3.wav
# ./eight/352ffbe3_nohash_0.wav
# ./eight/171edea9_nohash_4.wav
# ./eight/df038de4_nohash_0.wav
# ./eight/cdee383b_nohash_0.wav
# ./eight/40115b19_nohash_1.wav
# ./eight/25e95412_nohash_1.wav
# ./eight/69a1a79f_nohash_1.wav
# ./eight/823353e5_nohash_0.wav
# ./eight/0717b9f6_nohash_0.wav
# ./eight/3565ca83_nohash_0.wav
# ./eight/56f8a100_nohash_0.wav
# ./eight/bfd26d6b_nohash_0.wav
# ./eight/eb0676ec_nohash_4.wav
# ./eight/214ccb20_nohash_0.wav
# ./eight/735845ab_nohash_1.wav
# ./eight/2275edbb_nohash_0.wav
# ./eight/bfaf2000_nohash_0.wav
# ./eight/099d52ad_nohash_3.wav
# ./eight/8d4cdc60_nohash_0.wav
# ./eight/b9515bf3_nohash_2.wav
# ./eight/24a3e589_nohash_3.wav
# ./eight/bbf38549_nohash_3.wav
# ./eight/78102205_nohash_0.wav
# ./eight/590750e8_nohash_0.wav
# ./eight/d85270c1_nohash_1.wav
# ./eight/ab46af55_nohash_1.wav
# ./eight/765ffccb_nohash_0.wav
# ./eight/e4b02540_nohash_0.wav
# ./eight/9e46cfa1_nohash_0.wav
# ./eight/6d818f6c_nohash_0.wav
# ./eight/73cccfaf_nohash_0.wav
# ./eight/0819edb0_nohash_0.wav
# ./eight/0a196374_nohash_3.wav
# ./eight/6565a81d_nohash_2.wav
# ./eight/a5d1becc_nohash_0.wav
# ./eight/af6fbbf5_nohash_1.wav
# ./eight/91bed2e0_nohash_1.wav
# ./eight/2510c044_nohash_1.wav
# ./eight/9d8ac38b_nohash_2.wav
# ./eight/a9ca1818_nohash_2.wav
# ./eight/f4cae173_nohash_0.wav
# ./eight/cce7416f_nohash_4.wav
# ./eight/d5ca80c6_nohash_1.wav
# ./eight/a1e71565_nohash_2.wav
# ./eight/472b8045_nohash_0.wav
# ./eight/35d1b6ee_nohash_4.wav
# ./eight/9be15e93_nohash_4.wav
# ./eight/264f471d_nohash_1.wav
# ./eight/e6e29c47_nohash_0.wav
# ./eight/cb2929ce_nohash_1.wav
# ./eight/d0858dce_nohash_0.wav
# ./eight/5d0ab165_nohash_0.wav
# ./eight/36050ef3_nohash_4.wav
# ./eight/ccca5655_nohash_1.wav
# ./eight/f2e59fea_nohash_3.wav
# ./eight/3a69f765_nohash_1.wav
# ./eight/813b82a6_nohash_0.wav
# ./eight/23abe1c9_nohash_0.wav
# ./eight/15dd287d_nohash_0.wav
# ./eight/b80d6c5e_nohash_1.wav
# ./eight/8e05039f_nohash_4.wav
# ./eight/e0c782d5_nohash_2.wav
# ./eight/d0426d63_nohash_2.wav
# ./eight/c90c0105_nohash_0.wav
# ./eight/2b5e346d_nohash_1.wav
# ./eight/b17f5ba0_nohash_2.wav
# ./eight/61ab8fbc_nohash_3.wav
# ./eight/cce7416f_nohash_3.wav
# ./eight/5f9cd2eb_nohash_0.wav
# ./eight/0a2b400e_nohash_0.wav
# ./eight/caf1803e_nohash_0.wav
# ./eight/51c5601d_nohash_1.wav
# ./eight/beb458a4_nohash_4.wav
# ./eight/8dc26a15_nohash_0.wav
# ./eight/d5b963aa_nohash_1.wav
# ./eight/0b7ee1a0_nohash_4.wav
# ./eight/97f4c236_nohash_4.wav
# ./eight/616420be_nohash_1.wav
# ./eight/f6a380e7_nohash_1.wav
# ./eight/46a153d8_nohash_3.wav
# ./eight/0bfec55f_nohash_0.wav
# ./eight/5a98d407_nohash_0.wav
# ./eight/87070229_nohash_3.wav
# ./eight/64f83f0e_nohash_1.wav
# ./eight/ccb1266b_nohash_0.wav
# ./eight/7cfb1618_nohash_0.wav
# ./eight/ce7a8e92_nohash_0.wav
# ./eight/f4f59743_nohash_0.wav
# ./eight/682e1687_nohash_0.wav
# ./eight/0f46028a_nohash_3.wav
# ./eight/2a1f4853_nohash_3.wav
# ./eight/ccca5655_nohash_4.wav
# ./eight/a685a59d_nohash_0.wav
# ./eight/aa80f517_nohash_1.wav
# ./eight/6c0f6493_nohash_1.wav
# ./eight/1fc04a13_nohash_0.wav
# ./eight/4995d875_nohash_3.wav
# ./eight/2296b1af_nohash_0.wav
# ./eight/ccfd721c_nohash_1.wav
# ./eight/6a861f21_nohash_1.wav
# ./eight/333d7ddb_nohash_3.wav
# ./eight/f0522ff4_nohash_4.wav
# ./eight/cb2929ce_nohash_2.wav
# ./eight/ac9dee0e_nohash_0.wav
# ./eight/ab7b5acd_nohash_0.wav
# ./eight/9886d8bf_nohash_3.wav
# ./eight/8c7c9168_nohash_1.wav
# ./eight/cce7416f_nohash_0.wav
# ./eight/f0659908_nohash_0.wav
# ./eight/05cf43ef_nohash_0.wav
# ./eight/fa57ab3b_nohash_3.wav
# ./eight/05b2db80_nohash_0.wav
# ./eight/893705bb_nohash_1.wav
# ./eight/40115b19_nohash_0.wav
# ./eight/559bc36a_nohash_1.wav
# ./eight/96d8bb6f_nohash_1.wav
# ./eight/b0ae6326_nohash_0.wav
# ./eight/645ed69d_nohash_2.wav
# ./eight/c7dc7278_nohash_2.wav
# ./eight/3e549219_nohash_2.wav
# ./eight/30f31e42_nohash_1.wav
# ./eight/f5341341_nohash_4.wav
# ./eight/ddedba85_nohash_3.wav
# ./eight/6124b431_nohash_0.wav
# ./eight/3d9bbe2d_nohash_1.wav
# ./eight/9b5815cd_nohash_0.wav
# ./eight/0717b9f6_nohash_2.wav
# ./eight/ace072ba_nohash_4.wav
# ./eight/a7200079_nohash_2.wav
# ./eight/0137b3f4_nohash_1.wav
# ./eight/ddedba85_nohash_4.wav
# ./eight/195c120a_nohash_0.wav
# ./eight/1bb6ed89_nohash_1.wav
# ./eight/fa57ab3b_nohash_1.wav
# ./eight/748cb308_nohash_0.wav
# ./eight/06f6c194_nohash_1.wav
# ./eight/c6ee87a7_nohash_1.wav
# ./eight/d9b50b8b_nohash_0.wav
# ./eight/ae82c78c_nohash_2.wav
# ./eight/66276b0e_nohash_0.wav
# ./eight/b59fa113_nohash_0.wav
# ./eight/283d7a53_nohash_0.wav
# ./eight/83957201_nohash_0.wav
# ./eight/f44f440f_nohash_1.wav
# ./eight/c50f55b8_nohash_0.wav
# ./eight/d874a786_nohash_0.wav
# ./eight/53fd1780_nohash_0.wav
# ./eight/226537ab_nohash_3.wav
# ./eight/b9f46737_nohash_1.wav
# ./eight/a77fbcfd_nohash_4.wav
# ./eight/ddedba85_nohash_14.wav
# ./eight/5c39594f_nohash_2.wav
# ./eight/0a196374_nohash_1.wav
# ./eight/0c40e715_nohash_0.wav
# ./eight/09a7aa2a_nohash_0.wav
# ./eight/ef77b778_nohash_4.wav
# ./eight/d962e5ac_nohash_0.wav
# ./eight/81332c92_nohash_1.wav
# ./eight/412c675c_nohash_0.wav
# ./eight/824e8ce5_nohash_1.wav
# ./eight/3a929277_nohash_1.wav
# ./eight/3f45a0cf_nohash_1.wav
# ./eight/caf1803e_nohash_1.wav
# ./eight/cdee383b_nohash_1.wav
# ./eight/563aa4e6_nohash_2.wav
# ./eight/274c008f_nohash_0.wav
# ./eight/67bdbf56_nohash_0.wav
# ./eight/b737ee80_nohash_0.wav
# ./eight/ce0cb033_nohash_1.wav
# ./eight/611d2b50_nohash_1.wav
# ./eight/9b8a7439_nohash_0.wav
# ./eight/656e8bb3_nohash_1.wav
# ./eight/856eb138_nohash_2.wav
# ./eight/07363607_nohash_0.wav
# ./eight/234d6a48_nohash_1.wav
# ./eight/a4e8a997_nohash_0.wav
# ./eight/037c445a_nohash_0.wav
# ./eight/1093c8e7_nohash_1.wav
# ./eight/471a0925_nohash_0.wav
# ./eight/a5d485dc_nohash_2.wav
# ./eight/0ab3b47d_nohash_1.wav
# ./eight/256c0a05_nohash_3.wav
# ./eight/833d9f56_nohash_3.wav
# ./eight/9d32f10a_nohash_1.wav
# ./eight/7f9eb952_nohash_0.wav
# ./eight/f2b8fc18_nohash_0.wav
# ./eight/9e44aca3_nohash_0.wav
# ./eight/a7acbbeb_nohash_2.wav
# ./eight/01bcfc0c_nohash_2.wav
# ./eight/5fadb538_nohash_1.wav
# ./eight/b91b718c_nohash_3.wav
# ./eight/578d3efb_nohash_2.wav
# ./eight/62641b88_nohash_0.wav
# ./eight/0e17f595_nohash_1.wav
# ./eight/826268f8_nohash_0.wav
# ./eight/b7a0754f_nohash_4.wav
# ./eight/ca4912b6_nohash_0.wav
# ./eight/e718c302_nohash_0.wav
# ./eight/b2fbe484_nohash_0.wav
# ./eight/b575b5fb_nohash_0.wav
# ./eight/f035e2ea_nohash_3.wav
# ./eight/64220627_nohash_1.wav
# ./eight/86f12ac0_nohash_0.wav
# ./eight/07c5129e_nohash_0.wav
# ./eight/01b4757a_nohash_1.wav
# ./eight/11860c84_nohash_2.wav
# ./eight/978240e1_nohash_2.wav
# ./eight/b9f46737_nohash_0.wav
# ./eight/069ab0d5_nohash_2.wav
# ./eight/ed032775_nohash_0.wav
# ./eight/18a8f03f_nohash_2.wav
# ./eight/f9bdf10e_nohash_0.wav
# ./eight/692a88e6_nohash_2.wav
# ./eight/a1e71565_nohash_1.wav
# ./eight/332d33b1_nohash_0.wav
# ./eight/51055bda_nohash_1.wav
# ./eight/605ed0ff_nohash_0.wav
# ./eight/cc8b3228_nohash_1.wav
# ./eight/113b3fbc_nohash_2.wav
# ./eight/825f450d_nohash_0.wav
# ./eight/b00c4c53_nohash_0.wav
# ./eight/7d6b4b10_nohash_1.wav
# ./eight/b2ae3928_nohash_1.wav
# ./eight/69a1a79f_nohash_2.wav
# ./eight/171b56dc_nohash_0.wav
# ./eight/d9e9f554_nohash_0.wav
# ./eight/2144be19_nohash_1.wav
# ./eight/a929f9b9_nohash_2.wav
# ./eight/a709ddd3_nohash_1.wav
# ./eight/a69b9b3e_nohash_0.wav
# ./eight/d1dd03ed_nohash_3.wav
# ./eight/1c84a139_nohash_0.wav
# ./eight/8a90cf67_nohash_3.wav
# ./eight/0ff728b5_nohash_3.wav
# ./eight/2a1f4853_nohash_2.wav
# ./eight/cb72dfb6_nohash_2.wav
# ./eight/e9323bd9_nohash_0.wav
# ./eight/5184ed3e_nohash_1.wav
# ./eight/324210dd_nohash_5.wav
# ./eight/ae82c78c_nohash_1.wav
# ./eight/1c3f4fac_nohash_0.wav
# ./eight/35c8fa78_nohash_1.wav
# ./eight/ca4d5368_nohash_2.wav
# ./eight/07089da9_nohash_1.wav
# ./eight/e5afa9b0_nohash_0.wav
# ./eight/5fb88f4c_nohash_1.wav
# ./eight/5c39594f_nohash_1.wav
# ./eight/c2bc4489_nohash_0.wav
# ./eight/1c84a139_nohash_1.wav
# ./eight/3a33d3a4_nohash_0.wav
# ./eight/270bfa52_nohash_0.wav
# ./eight/aff582a1_nohash_2.wav
# ./eight/51f7a034_nohash_2.wav
# ./eight/dcbfe008_nohash_0.wav
# ./eight/59b98a22_nohash_0.wav
# ./eight/f9f9751d_nohash_1.wav
# ./eight/190821dc_nohash_1.wav
# ./eight/31601aad_nohash_0.wav
# ./eight/21832144_nohash_0.wav
# ./eight/4fd1443e_nohash_1.wav
# ./eight/be7a5b2d_nohash_2.wav
# ./eight/65ec06e5_nohash_0.wav
# ./eight/20a0d54b_nohash_0.wav
# ./eight/a55105d0_nohash_1.wav
# ./eight/7846fd85_nohash_3.wav
# ./eight/2bdbe5f7_nohash_1.wav
# ./eight/d926bb17_nohash_1.wav
# ./eight/964e8cfd_nohash_1.wav
# ./eight/9a5db2cb_nohash_1.wav
# ./eight/3ee0fc39_nohash_0.wav
# ./eight/0cb74144_nohash_4.wav
# ./eight/01bb6a2a_nohash_0.wav
# ./eight/9d8ac38b_nohash_0.wav
# ./eight/888a0c49_nohash_2.wav
# ./eight/324210dd_nohash_1.wav
# ./eight/35d1b6ee_nohash_0.wav
# ./eight/743edf9d_nohash_0.wav
# ./eight/152491bc_nohash_2.wav
# ./eight/105e72bb_nohash_1.wav
# ./eight/bd76a7fd_nohash_2.wav
# ./eight/24a3e589_nohash_4.wav
# ./eight/e6327279_nohash_3.wav
# ./eight/f2e59fea_nohash_0.wav
# ./eight/017c4098_nohash_4.wav
# ./eight/ec201020_nohash_1.wav
# ./eight/92a9c5e6_nohash_2.wav
# ./eight/4874a7e9_nohash_0.wav
# ./eight/e9abfe31_nohash_0.wav
# ./eight/d3831f6a_nohash_1.wav
# ./eight/1c76f5f3_nohash_0.wav
# ./eight/68effe85_nohash_0.wav
# ./eight/07089da9_nohash_0.wav
# ./eight/b63fea9e_nohash_2.wav
# ./eight/96d5276f_nohash_0.wav
# ./eight/c099668c_nohash_2.wav
# ./eight/d070ea86_nohash_1.wav
# ./eight/72320401_nohash_1.wav
# ./eight/90e72357_nohash_2.wav
# ./eight/dce05676_nohash_0.wav
# ./eight/3e31dffe_nohash_3.wav
# ./eight/fe1916ba_nohash_0.wav
# ./eight/35d1b6ee_nohash_2.wav
# ./eight/5f5eef60_nohash_2.wav
# ./eight/0d90d8e1_nohash_2.wav
# ./eight/c634a189_nohash_4.wav
# ./eight/fa52ddf6_nohash_1.wav
# ./eight/9b8a7439_nohash_3.wav
# ./eight/cb2929ce_nohash_0.wav
# ./eight/f8ba7c0e_nohash_0.wav
# ./eight/f5626af6_nohash_3.wav
# ./eight/25e95412_nohash_0.wav
# ./eight/d7a58714_nohash_0.wav
# ./eight/620ff0fa_nohash_0.wav
# ./eight/73cccfaf_nohash_1.wav
# ./eight/6c6aa323_nohash_1.wav
# ./eight/837a0f64_nohash_2.wav
# ./eight/31267b59_nohash_0.wav
# ./eight/e7117d00_nohash_1.wav
# ./eight/d962e5ac_nohash_2.wav
# ./eight/ed07d5b7_nohash_0.wav
# ./eight/4c6944d6_nohash_6.wav
# ./eight/563aa4e6_nohash_4.wav
# ./eight/b959cd0c_nohash_0.wav
# ./eight/2e75d37a_nohash_2.wav
# ./eight/779de043_nohash_1.wav
# ./eight/15574821_nohash_1.wav
# ./eight/122c5aa7_nohash_3.wav
# ./eight/a489191a_nohash_4.wav
# ./eight/ad63d93c_nohash_4.wav
# ./eight/686d030b_nohash_4.wav
# ./eight/2dce72b3_nohash_1.wav
# ./eight/b3bb4dd6_nohash_0.wav
# ./eight/61abbf52_nohash_3.wav
# ./eight/c5a1e46c_nohash_3.wav
# ./eight/32561e9e_nohash_0.wav
# ./eight/7fd25f7c_nohash_3.wav
# ./eight/fb8c31a9_nohash_3.wav
# ./eight/0ff728b5_nohash_1.wav
# ./eight/e269bac0_nohash_0.wav
# ./eight/54412eae_nohash_0.wav
# ./eight/a489191a_nohash_2.wav
# ./eight/bdd22e4d_nohash_0.wav
# ./eight/5e3b7a84_nohash_0.wav
# ./eight/f1d36c53_nohash_1.wav
# ./eight/2bfe70ef_nohash_0.wav
# ./eight/708a9569_nohash_0.wav
# ./eight/b4ea0d9a_nohash_5.wav
# ./eight/b87bdb22_nohash_1.wav
# ./eight/8dc18a75_nohash_2.wav
# ./eight/f84762e5_nohash_0.wav
# ./eight/211b928a_nohash_3.wav
# ./eight/f618568f_nohash_0.wav
# ./eight/e9e07a2d_nohash_1.wav
# ./eight/8e080ece_nohash_0.wav
# ./eight/62f05757_nohash_4.wav
# ./eight/826268f8_nohash_1.wav
# ./eight/0ea0e2f4_nohash_0.wav
# ./eight/c50f55b8_nohash_2.wav
# ./eight/cc4f9250_nohash_1.wav
# ./eight/8012c69d_nohash_2.wav
# ./eight/beb458a4_nohash_2.wav
# ./eight/72be9202_nohash_0.wav
# ./eight/c4500713_nohash_1.wav
# ./eight/462e1919_nohash_0.wav
# ./eight/bdd22e4d_nohash_4.wav
# ./eight/6071a214_nohash_0.wav
# ./eight/833d9f56_nohash_0.wav
# ./eight/c79159aa_nohash_4.wav
# ./eight/da27460c_nohash_1.wav
# ./eight/bbf38549_nohash_2.wav
# ./eight/1b42b551_nohash_0.wav
# ./eight/a77fbcfd_nohash_0.wav
# ./eight/ee1d8d49_nohash_3.wav
# ./eight/c842b5e4_nohash_1.wav
# ./eight/a591c2ea_nohash_1.wav
# ./eight/3291330e_nohash_4.wav
# ./eight/3bb68054_nohash_0.wav
# ./eight/fb727898_nohash_2.wav
# ./eight/c0445658_nohash_2.wav
# ./eight/8a325749_nohash_1.wav
# ./eight/28ed6bc9_nohash_0.wav
# ./eight/2ce7534c_nohash_1.wav
# ./eight/3ed3e49a_nohash_0.wav
# ./eight/712e4d58_nohash_0.wav
# ./eight/75b631ff_nohash_0.wav
# ./eight/857366dd_nohash_1.wav
# ./eight/6ef76186_nohash_0.wav
# ./eight/067f61e2_nohash_2.wav
# ./eight/050170cb_nohash_1.wav
# ./eight/f822b9bf_nohash_4.wav
# ./eight/2005ca25_nohash_0.wav
# ./eight/0d6d7360_nohash_0.wav
# ./eight/96a48d28_nohash_0.wav
# ./eight/ab5d7179_nohash_0.wav
# ./eight/f01a0d63_nohash_2.wav
# ./eight/5a98d407_nohash_3.wav
# ./eight/de3fe344_nohash_3.wav
# ./eight/41285056_nohash_0.wav
# ./eight/bd76a7fd_nohash_0.wav
# ./eight/f0659908_nohash_4.wav
# ./eight/becd5a53_nohash_0.wav
# ./eight/01bb6a2a_nohash_1.wav
# ./eight/9448c397_nohash_0.wav
# ./eight/ff2b842e_nohash_3.wav
# ./eight/bcdaa7a9_nohash_0.wav
# ./eight/1a892463_nohash_1.wav
# ./eight/75b631ff_nohash_1.wav
# ./eight/4c13fe25_nohash_0.wav
# ./eight/db24628d_nohash_4.wav
# ./eight/1e02ffc5_nohash_4.wav
# ./eight/692a88e6_nohash_1.wav
# ./eight/3d86b69a_nohash_2.wav
# ./eight/3cfc6b3a_nohash_0.wav
# ./eight/b6ebe225_nohash_0.wav
# ./eight/ec989d6d_nohash_3.wav
# ./eight/9886d8bf_nohash_2.wav
# ./eight/3bc21161_nohash_0.wav
# ./eight/efab2cbd_nohash_0.wav
# ./eight/837a0f64_nohash_3.wav
# ./eight/da76aa58_nohash_0.wav
# ./eight/29229c21_nohash_4.wav
# ./eight/dea820ce_nohash_4.wav
# ./eight/88b7c5fa_nohash_0.wav
# ./eight/2cec1d47_nohash_0.wav
# ./eight/6e916de8_nohash_0.wav
# ./eight/63996b7c_nohash_2.wav
# ./eight/6cf5459b_nohash_0.wav
# ./eight/dbb7723a_nohash_1.wav
# ./eight/5f9cd2eb_nohash_1.wav
# ./eight/f1d8a638_nohash_1.wav
# ./eight/e11fbc6e_nohash_2.wav
# ./eight/1efdf53f_nohash_0.wav
# ./eight/ec201020_nohash_0.wav
# ./eight/e1469561_nohash_3.wav
# ./eight/a05a90c1_nohash_3.wav
# ./eight/ab3f0c1b_nohash_3.wav
# ./eight/3bb68054_nohash_4.wav
# ./eight/29dce108_nohash_1.wav
# ./eight/f4504600_nohash_0.wav
# ./eight/9785931e_nohash_0.wav
# ./eight/ad63d93c_nohash_1.wav
# ./eight/246d2c7f_nohash_0.wav
# ./eight/34805883_nohash_0.wav
# ./eight/e0315cf6_nohash_1.wav
# ./eight/778a4a01_nohash_1.wav
# ./eight/ea356919_nohash_0.wav
# ./eight/365908bd_nohash_4.wav
# ./eight/2a0b413e_nohash_1.wav
# ./eight/27b9a84f_nohash_0.wav
# ./eight/caa4779f_nohash_0.wav
# ./eight/ca4d5368_nohash_4.wav
# ./eight/bfd26d6b_nohash_2.wav
# ./eight/40b60ae9_nohash_0.wav
# ./eight/bfb10243_nohash_0.wav
# ./eight/c87a578d_nohash_0.wav
# ./eight/e900b652_nohash_0.wav
# ./eight/d056d4d8_nohash_0.wav
# ./eight/9c06a3f3_nohash_0.wav
# ./eight/b528edb3_nohash_0.wav
# ...
# ./follow/fd5ccd39_nohash_0.wav
# ./follow/b0f5b16d_nohash_1.wav
# ./follow/617aeb6c_nohash_2.wav
# ./follow/a05a90c1_nohash_1.wav
# ./follow/508e30ee_nohash_0.wav
# ./follow/e71a9381_nohash_2.wav
# ./follow/8b25410a_nohash_2.wav
# ./follow/ccca5655_nohash_2.wav
# ./follow/4e99c1b7_nohash_1.wav
# ./follow/61e2f74f_nohash_0.wav
# ./follow/a7acbbeb_nohash_0.wav
# ./follow/3d9bbe2d_nohash_3.wav
# ./follow/0585b66d_nohash_1.wav
# ./follow/f822b9bf_nohash_0.wav
# ./follow/3108acca_nohash_0.wav
# ./follow/d394ef8e_nohash_4.wav
# ./follow/a2cc5444_nohash_3.wav
# ./follow/067f61e2_nohash_0.wav
# ./follow/d1dd03ed_nohash_2.wav
# ./follow/b4ea0d9a_nohash_0.wav
# ./follow/3bb68054_nohash_2.wav
# ./follow/0f46028a_nohash_4.wav
# ./follow/856eb138_nohash_3.wav
# ./follow/1dc86f91_nohash_2.wav
# ./follow/ed032775_nohash_3.wav
# ./follow/51c5601d_nohash_0.wav
# ./follow/72e382bd_nohash_0.wav
# ./follow/f30285c8_nohash_3.wav
# ./follow/978240e1_nohash_1.wav
# ./follow/f568162b_nohash_2.wav
# ./follow/2927c601_nohash_3.wav
# ./follow/18ffa72d_nohash_0.wav
# ./follow/472b8045_nohash_2.wav
# ./follow/00970ce1_nohash_0.wav
# ./follow/3102f006_nohash_0.wav
# ./follow/65846c5f_nohash_1.wav
# ./follow/a04817c2_nohash_1.wav
# ./follow/2356b88d_nohash_3.wav
# ./follow/2fcb6397_nohash_3.wav
# ./follow/c7e02d9c_nohash_0.wav
# ./follow/6124b431_nohash_1.wav
# ./follow/9b8a7439_nohash_2.wav
# ./follow/f5626af6_nohash_2.wav
# ./follow/0d82fd99_nohash_1.wav
# ./follow/2fcb6397_nohash_0.wav
# ./follow/85851131_nohash_1.wav
# ./follow/ace072ba_nohash_2.wav
# ./follow/460209ac_nohash_3.wav
# ./follow/196e84b7_nohash_1.wav
# ./follow/26631bee_nohash_0.wav
# ./follow/19414a96_nohash_0.wav
# ./follow/9f93e408_nohash_3.wav
# ./follow/cdee383b_nohash_2.wav
# ./follow/eeaf97c3_nohash_1.wav
# ./follow/72242187_nohash_3.wav
# ./follow/195c120a_nohash_1.wav
# ./follow/cc4f9250_nohash_3.wav
# ./follow/30f6e665_nohash_0.wav
# ./follow/45692b02_nohash_1.wav
# ./follow/24a3e589_nohash_1.wav
# ./follow/90e72357_nohash_1.wav
# ./follow/23da904f_nohash_0.wav
# ./follow/fa57ab3b_nohash_2.wav
# ./follow/da27460c_nohash_0.wav
# ./follow/bcf614a2_nohash_2.wav
# ./follow/b4ea0d9a_nohash_6.wav
# ./follow/7213ed54_nohash_1.wav
# ./follow/2fee065a_nohash_3.wav
# ./follow/0b7ee1a0_nohash_2.wav
# ./follow/234d6a48_nohash_2.wav
# ./follow/7213ed54_nohash_3.wav
# ./follow/14c7b073_nohash_3.wav
# ./follow/195c120a_nohash_4.wav
# ./follow/f30285c8_nohash_4.wav
# ./follow/c5a1e46c_nohash_1.wav
# ./follow/25e95412_nohash_4.wav
# ./follow/98f4f088_nohash_0.wav
# ./follow/b29f8b23_nohash_1.wav
# ./follow/879a2b38_nohash_2.wav
# ./follow/63f042c6_nohash_0.wav
# ./follow/954f190f_nohash_4.wav
# ./follow/fc3ba625_nohash_1.wav
# ./follow/66e8a4ec_nohash_0.wav
# ./follow/ccca5655_nohash_0.wav
# ./follow/7d6b4b10_nohash_2.wav
# ./follow/5104f2f4_nohash_1.wav
# ./follow/1a994c9f_nohash_0.wav
# ./follow/5104f2f4_nohash_0.wav
# ./follow/acfd5b5e_nohash_4.wav
# ./follow/b8874962_nohash_2.wav
# ./follow/a1cf7fd8_nohash_2.wav
# ./follow/7e7ca854_nohash_0.wav
# ./follow/827421c4_nohash_0.wav
# ./follow/0ba018fc_nohash_2.wav
# ./follow/a2cc5444_nohash_0.wav
# ./follow/c5a1e46c_nohash_4.wav
# ./follow/b0f5b16d_nohash_2.wav
# ./follow/29229c21_nohash_1.wav
# ./follow/42f81601_nohash_4.wav
# ./follow/9a76f8c3_nohash_3.wav
# ./follow/fa52ddf6_nohash_2.wav
# ./follow/b69002d4_nohash_2.wav
# ./follow/98ea0818_nohash_1.wav
# ./follow/63f7a489_nohash_3.wav
# ./follow/a6f2fd71_nohash_1.wav
# ./follow/6c88cf25_nohash_0.wav
# ./follow/60402b64_nohash_0.wav
# ./follow/b69fe0e2_nohash_0.wav
# ./follow/b414c653_nohash_4.wav
# ./follow/d264f7b6_nohash_4.wav
# ./follow/b69fe0e2_nohash_2.wav
# ./follow/08ab231c_nohash_0.wav
# ./follow/3bb68054_nohash_1.wav
# ./follow/779de043_nohash_0.wav
# ./follow/87070229_nohash_4.wav
# ./follow/3d86b69a_nohash_0.wav
# ./follow/af790082_nohash_2.wav
# ./follow/322d17d3_nohash_1.wav
# ./follow/cb72dfb6_nohash_0.wav
# ./follow/460209ac_nohash_2.wav
# ./follow/61e2f74f_nohash_1.wav
# ./follow/96d8bb6f_nohash_3.wav
# ./follow/db9cfc88_nohash_0.wav
# ./follow/7e7ca854_nohash_3.wav
# ./follow/6969e51a_nohash_1.wav
# ./follow/d3831f6a_nohash_2.wav
# ./follow/012187a4_nohash_0.wav
# ./follow/fb8c31a9_nohash_2.wav
# ./follow/878befa7_nohash_2.wav
# ./follow/a4effc43_nohash_0.wav
# ./follow/fc3ba625_nohash_4.wav
# ./follow/ace072ba_nohash_3.wav
# ./follow/e1936ce8_nohash_1.wav
# ./follow/5f5eef60_nohash_1.wav
# ./follow/195c120a_nohash_2.wav
# ./follow/30276d03_nohash_4.wav
# ./follow/3d9bbe2d_nohash_0.wav
# ./follow/6904f0cb_nohash_1.wav
# ./follow/8e523821_nohash_1.wav
# ./follow/954f190f_nohash_3.wav
# ./follow/fe11e258_nohash_0.wav
# ./follow/f5341341_nohash_2.wav
# ./follow/81332c92_nohash_4.wav
# ./follow/3c4aa5ef_nohash_1.wav
# ./follow/f8ba7c0e_nohash_1.wav
# ./follow/9ef5db3c_nohash_0.wav
# ./follow/bdd22e4d_nohash_3.wav
# ./follow/a9ca1818_nohash_3.wav
# ./follow/87d5e978_nohash_0.wav
# ./follow/7d6b4b10_nohash_3.wav
# ./follow/e6327279_nohash_0.wav
# ./follow/5f1253e9_nohash_0.wav
# ./follow/879a2b38_nohash_3.wav
# ./follow/b5cf6ea8_nohash_10.wav
# ./follow/f8ba7c0e_nohash_4.wav
# ./follow/e9abfe31_nohash_3.wav
# ./follow/bb05582b_nohash_3.wav
# ./follow/3a3ee7ed_nohash_0.wav
# ./follow/9fac5701_nohash_0.wav
# ./follow/2a1f4853_nohash_1.wav
# ./follow/3a929277_nohash_0.wav
# ./follow/513aeddf_nohash_2.wav
# ./follow/5cf1ecce_nohash_0.wav
# ./follow/954f190f_nohash_1.wav
# ./follow/a77fbcfd_nohash_3.wav
# ./follow/4e99c1b7_nohash_3.wav
# ./follow/322d17d3_nohash_0.wav
# ./follow/fbb2f6cc_nohash_0.wav
# ./follow/a7acbbeb_nohash_1.wav
# ./follow/189cbabe_nohash_1.wav
# ./follow/773e26f7_nohash_1.wav
# ./follow/b5cf6ea8_nohash_9.wav
# ./follow/31ac8b88_nohash_0.wav
# ./follow/63f7a489_nohash_2.wav
# ./follow/113b3fbc_nohash_1.wav
# ./follow/462dca36_nohash_0.wav
# ./follow/a293e285_nohash_0.wav
# ./follow/eeaf97c3_nohash_4.wav
# ./follow/d962e5ac_nohash_3.wav
# ./follow/4e99c1b7_nohash_2.wav
# ./follow/29dce108_nohash_0.wav
# ./follow/d070ea86_nohash_3.wav
# ./follow/f2e9b610_nohash_2.wav
# ./follow/559bc36a_nohash_0.wav
# ./follow/fbb2f6cc_nohash_2.wav
# ./follow/3659fc1c_nohash_0.wav
# ./follow/db24628d_nohash_2.wav
# ./follow/878befa7_nohash_0.wav
# ./follow/ad526ada_nohash_0.wav
# ./follow/bbf38549_nohash_1.wav
# ./follow/3a69f765_nohash_3.wav
# ./follow/f1d8a638_nohash_0.wav
# ./follow/c50f55b8_nohash_1.wav
# ./follow/4c594e0f_nohash_0.wav
# ./follow/8769c34c_nohash_2.wav
# ./follow/e71a9381_nohash_1.wav
# ./follow/fb8c31a9_nohash_0.wav
# ./follow/365908bd_nohash_3.wav
# ./follow/8dc18a75_nohash_3.wav
# ./follow/1e02ffc5_nohash_2.wav
# ./follow/ee1d8d49_nohash_1.wav
# ./follow/a7200079_nohash_4.wav
# ./follow/ff2b842e_nohash_0.wav
# ./follow/f798ac78_nohash_1.wav
# ./follow/b308773d_nohash_0.wav
# ./follow/a1e71565_nohash_0.wav
# ./follow/bdd22e4d_nohash_1.wav
# ./follow/0d82fd99_nohash_0.wav
# ./follow/acfd5b5e_nohash_3.wav
# ./follow/32ad5b65_nohash_2.wav
# ./follow/2aca1e72_nohash_3.wav
# ./follow/a293e285_nohash_1.wav
# ./follow/fa52ddf6_nohash_0.wav
# ./follow/3a69f765_nohash_2.wav
# ./follow/3108acca_nohash_1.wav
# ./follow/fb7eb481_nohash_1.wav
# ./follow/5cf1ecce_nohash_4.wav
# ./follow/2748cce7_nohash_1.wav
# ./follow/d1dd03ed_nohash_1.wav
# ./follow/ebdd0f59_nohash_0.wav
# ./follow/f2898d06_nohash_0.wav
# ./follow/bcf614a2_nohash_0.wav
# ./follow/ace072ba_nohash_0.wav
# ./follow/cd671b5f_nohash_1.wav
# ./follow/07de53d3_nohash_2.wav
# ./follow/6bf5baf3_nohash_1.wav
# ./follow/f01a0d63_nohash_3.wav
# ./follow/fb7eb481_nohash_3.wav
# ./follow/9a76f8c3_nohash_2.wav
# ./follow/8fe67225_nohash_0.wav
# ./follow/1e9e6bdd_nohash_3.wav
# ./follow/9a76f8c3_nohash_1.wav
# ./follow/90e72357_nohash_4.wav
# ./follow/234d6a48_nohash_3.wav
# ./follow/f798ac78_nohash_2.wav
# ./follow/bde0f20a_nohash_3.wav
# ./follow/d21fd169_nohash_3.wav
# ./follow/6bf5baf3_nohash_2.wav
# ./follow/0585b66d_nohash_0.wav
# ./follow/0585b66d_nohash_2.wav
# ./follow/b528edb3_nohash_3.wav
# ./follow/b69002d4_nohash_1.wav
# ./follow/7f9eb952_nohash_2.wav
# ./follow/f2e9b610_nohash_0.wav
# ./follow/b2ae3928_nohash_3.wav
# ./follow/131e738d_nohash_2.wav
# ./follow/3ce4910e_nohash_1.wav
# ./follow/74241b28_nohash_4.wav
# ./follow/de89e2ca_nohash_2.wav
# ./follow/26631bee_nohash_1.wav
# ./follow/f0659908_nohash_3.wav
# ./follow/f568162b_nohash_1.wav
# ./follow/30060aba_nohash_1.wav
# ./follow/e4be0cf6_nohash_3.wav
# ./follow/9fac5701_nohash_1.wav
# ./follow/32ad5b65_nohash_1.wav
# ./follow/893705bb_nohash_4.wav
# ./follow/2aca1e72_nohash_5.wav
# ./follow/b5cf6ea8_nohash_7.wav
# ./follow/d264f7b6_nohash_3.wav
# ./follow/89947bd7_nohash_0.wav
# ./follow/fa52ddf6_nohash_4.wav
# ./follow/b91b718c_nohash_2.wav
# ./follow/2aca1e72_nohash_1.wav
# ./follow/b6026214_nohash_0.wav
# ./follow/352ffbe3_nohash_2.wav
# ./follow/ec989d6d_nohash_1.wav
# ./follow/3837f3f3_nohash_0.wav
# ./follow/890cc926_nohash_0.wav
# ./follow/5ebc1cda_nohash_3.wav
# ./follow/a55105d0_nohash_4.wav
# ./follow/b0f5b16d_nohash_4.wav
# ./follow/57152045_nohash_4.wav
# ./follow/256c0a05_nohash_2.wav
# ./follow/5ebc1cda_nohash_0.wav
# ./follow/51c5601d_nohash_2.wav
# ./follow/2e75d37a_nohash_3.wav
# ./follow/1496195a_nohash_0.wav
# ./follow/dae01802_nohash_2.wav
# ./follow/674ca5ea_nohash_0.wav
# ./follow/4c3cddb8_nohash_0.wav
# ./follow/fb8c31a9_nohash_1.wav
# ./follow/fa57ab3b_nohash_0.wav
# ./follow/235b444f_nohash_4.wav
# ./follow/3f45a0cf_nohash_0.wav
# ./follow/8dc18a75_nohash_1.wav
# ./follow/ef3367d9_nohash_4.wav
# ./follow/332d33b1_nohash_3.wav
# ./follow/f822b9bf_nohash_1.wav
# ./follow/27e6f0f0_nohash_0.wav
# ./follow/bd76a7fd_nohash_4.wav
# ./follow/8fe67225_nohash_1.wav
# ./follow/9f93e408_nohash_0.wav
# ./follow/475b61f1_nohash_1.wav
# ./follow/3102f006_nohash_2.wav
# ./follow/f5626af6_nohash_0.wav
# ./follow/bbc30633_nohash_3.wav
# ./follow/462dca36_nohash_1.wav
# ./follow/508e30ee_nohash_1.wav
# ./follow/85c5eaa0_nohash_0.wav
# ./follow/8e523821_nohash_0.wav
# ./follow/201e28a9_nohash_0.wav
# ./follow/3c4aa5ef_nohash_0.wav
# ./follow/ac9dee0e_nohash_1.wav
# ./follow/af6fbbf5_nohash_2.wav
# ./follow/435695e3_nohash_2.wav
# ./follow/4c3cddb8_nohash_1.wav
# ./follow/f5341341_nohash_1.wav
# ./follow/3b3d2f59_nohash_2.wav
# ./follow/2356b88d_nohash_0.wav
# ./follow/8e523821_nohash_3.wav
# ./follow/cfbedff9_nohash_1.wav
# ./follow/9e44aca3_nohash_1.wav
# ./follow/72e382bd_nohash_1.wav
# ./follow/54b6d355_nohash_0.wav
# ./follow/f2898d06_nohash_3.wav
# ./follow/ca5d184c_nohash_0.wav
# ./follow/1a994c9f_nohash_3.wav
# ./follow/2f0ce4d9_nohash_0.wav
# ./follow/b5cf6ea8_nohash_8.wav
# ./follow/211b928a_nohash_0.wav
# ./follow/24a3e589_nohash_0.wav
# ./follow/bb05582b_nohash_1.wav
# ./follow/352ffbe3_nohash_1.wav
# ./follow/2b5e346d_nohash_3.wav
# ./follow/bbc30633_nohash_1.wav
# ./follow/2f0ce4d9_nohash_1.wav
# ./follow/acfd5b5e_nohash_0.wav
# ./follow/3589bc72_nohash_1.wav
# ./follow/b5cf6ea8_nohash_5.wav
# ./follow/ddedba85_nohash_1.wav
# ./follow/cb72dfb6_nohash_1.wav
# ./follow/f2e9b610_nohash_3.wav
# ./follow/fc3ba625_nohash_2.wav
# ./follow/b6e6aa2e_nohash_0.wav
# ./follow/050170cb_nohash_0.wav
# ./follow/ff4ed4f3_nohash_0.wav
# ./follow/b6e6aa2e_nohash_1.wav
# ./follow/679463fc_nohash_2.wav
# ./follow/3cc595de_nohash_0.wav
# ./follow/f6a380e7_nohash_0.wav
# ./follow/a7216980_nohash_3.wav
# ./follow/b7e9f841_nohash_2.wav
# ./follow/559bc36a_nohash_2.wav
# ./follow/a80f9f53_nohash_0.wav
# ./follow/5f5eef60_nohash_4.wav
# ./follow/cc3b5b62_nohash_1.wav
# ./follow/a1cf7fd8_nohash_3.wav
# ./follow/b528edb3_nohash_1.wav
# ./follow/bdd22e4d_nohash_2.wav
# ./follow/f798ac78_nohash_3.wav
# ./follow/a7216980_nohash_0.wav
# ./follow/559bc36a_nohash_3.wav
# ./follow/5769c5ab_nohash_2.wav
# ./follow/b69002d4_nohash_3.wav
# ./follow/c98bbbd3_nohash_0.wav
# ./follow/73f20b00_nohash_1.wav
# ./follow/a2cc5444_nohash_2.wav
# ./follow/f568162b_nohash_0.wav
# ./follow/235b444f_nohash_2.wav
# ./follow/f8ba7c0e_nohash_3.wav
# ./follow/3b4f8f24_nohash_0.wav
# ./follow/a045368c_nohash_3.wav
# ./follow/6aa8def4_nohash_3.wav
# ./follow/6aa8def4_nohash_4.wav
# ./follow/890cc926_nohash_3.wav
# ./follow/23da904f_nohash_2.wav
# ./follow/64df20d8_nohash_2.wav
# ./follow/0d90d8e1_nohash_0.wav
# ./follow/54ad8f22_nohash_0.wav
# ./follow/4c6167ca_nohash_7.wav
# ./follow/0bfec55f_nohash_1.wav
# ./follow/ef3367d9_nohash_6.wav
# ./follow/12623a81_nohash_0.wav
# ./follow/5f9cd2eb_nohash_6.wav
# ./follow/f68160c0_nohash_0.wav
# ./follow/00970ce1_nohash_1.wav
# ./follow/189cbabe_nohash_0.wav
# ./follow/ddedba85_nohash_9.wav
# ./follow/1c84a139_nohash_2.wav
# ./follow/0ea9c8ce_nohash_1.wav
# ./follow/226537ab_nohash_2.wav
# ./follow/435695e3_nohash_4.wav
# ./follow/0c09f202_nohash_1.wav
# ./follow/7c83c5f6_nohash_1.wav
# ./follow/ceef6d96_nohash_2.wav
# ./follow/14c7b073_nohash_0.wav
# ./follow/c351e611_nohash_1.wav
# ./follow/559bc36a_nohash_4.wav
# ./follow/1e9e6bdd_nohash_1.wav
# ./follow/a55105d0_nohash_0.wav
# ./follow/d5b963aa_nohash_3.wav
# ./follow/ede2f4ee_nohash_0.wav
# ./follow/ddedba85_nohash_5.wav
# ./follow/beb458a4_nohash_3.wav
# ./follow/256c0a05_nohash_1.wav
# ./follow/508e30ee_nohash_2.wav
# ./follow/674ca5ea_nohash_1.wav
# ./follow/322d17d3_nohash_3.wav
# ./follow/81332c92_nohash_0.wav
# ./follow/42a99aec_nohash_1.wav
# ./follow/d070ea86_nohash_2.wav
# ./follow/94d370bf_nohash_1.wav
# ./follow/a04817c2_nohash_0.wav
# ./follow/6ef407da_nohash_1.wav
# ./follow/c41d9052_nohash_0.wav
# ./follow/322d17d3_nohash_2.wav
# ./follow/cb62dbf1_nohash_0.wav
# ./follow/042a8dde_nohash_2.wav
# ./follow/332d33b1_nohash_2.wav
# ./follow/2927c601_nohash_0.wav
# ./follow/a55105d0_nohash_3.wav
# ./follow/508e30ee_nohash_3.wav
# ./follow/0b7ee1a0_nohash_0.wav
# ./follow/1ed0b13d_nohash_3.wav
# ./follow/91ffb786_nohash_0.wav
# ./follow/81332c92_nohash_3.wav
# ./follow/6c88cf25_nohash_1.wav
# ./follow/9151f184_nohash_3.wav
# ./follow/54ad8f22_nohash_3.wav
# ./follow/dd664d92_nohash_0.wav
# ./follow/4649256f_nohash_2.wav
# ./follow/9448c397_nohash_3.wav
# ./follow/89947bd7_nohash_3.wav
# ./follow/2927c601_nohash_1.wav
# ./follow/5cf1ecce_nohash_2.wav
# ./follow/365908bd_nohash_0.wav
# ./follow/3cc595de_nohash_1.wav
# ./follow/7e7ca854_nohash_1.wav
# ./follow/fd5ccd39_nohash_1.wav
# ./follow/333d7ddb_nohash_2.wav
# ./follow/1e9e6bdd_nohash_0.wav
# ./follow/235b444f_nohash_0.wav
# ./follow/0f46028a_nohash_2.wav
# ./follow/d1dd03ed_nohash_0.wav
# ./follow/e882abb2_nohash_2.wav
# ./follow/3c4aa5ef_nohash_2.wav
# ./follow/1dc86f91_nohash_0.wav
# ./follow/4c6167ca_nohash_0.wav
# ./follow/b5cf6ea8_nohash_2.wav
# ./follow/617aeb6c_nohash_3.wav
# ./follow/06f6c194_nohash_0.wav
# ./follow/1ed0b13d_nohash_4.wav
# ./follow/645ed69d_nohash_0.wav
# ./follow/2aca1e72_nohash_4.wav
# ./follow/67bdbf56_nohash_1.wav
# ./follow/02ade946_nohash_2.wav
# ./follow/63f7a489_nohash_1.wav
# ./follow/6ef407da_nohash_2.wav
# ./follow/9be15e93_nohash_1.wav
# ./follow/c351e611_nohash_4.wav
# ./follow/4e6902d0_nohash_0.wav
# ./follow/3d9bbe2d_nohash_2.wav
# ./follow/63f7a489_nohash_0.wav
# ./follow/69a1a79f_nohash_3.wav
# ./follow/c741d0df_nohash_0.wav
# ./follow/94d370bf_nohash_2.wav
# ./follow/b69fe0e2_nohash_4.wav
# ./follow/4c6944d6_nohash_3.wav
# ./follow/1b42b551_nohash_1.wav
# ./follow/82d0d3ba_nohash_0.wav
# ./follow/645ed69d_nohash_1.wav
# ./follow/d21fd169_nohash_0.wav
# ./follow/773e26f7_nohash_4.wav
# ./follow/32ad5b65_nohash_0.wav
# ./follow/dac8b7f9_nohash_0.wav
# ./follow/a95dbfd4_nohash_1.wav
# ./follow/4c6944d6_nohash_0.wav
# ./follow/0a2b400e_nohash_2.wav
# ./follow/ee6163d5_nohash_1.wav
# ./follow/bde0f20a_nohash_1.wav
# ./follow/b4ea0d9a_nohash_2.wav
# ./follow/893705bb_nohash_8.wav
# ./follow/64df20d8_nohash_1.wav
# ./follow/18f8afd5_nohash_2.wav
# ./follow/34d5aa5a_nohash_1.wav
# ./follow/0f7266cf_nohash_0.wav
# ./follow/ca4912b6_nohash_1.wav
# ./follow/31f01a8d_nohash_4.wav
# ./follow/e9abfe31_nohash_1.wav
# ./follow/ef3367d9_nohash_1.wav
# ./follow/cd671b5f_nohash_0.wav
# ./follow/06f6c194_nohash_3.wav
# ./follow/9be15e93_nohash_3.wav
# ./follow/3b195250_nohash_2.wav
# ./follow/7c86c03e_nohash_0.wav
# ./follow/c5a1e46c_nohash_0.wav
# ./follow/4cee0c60_nohash_2.wav
# ./follow/2c5e0347_nohash_0.wav
# ./follow/0f7266cf_nohash_3.wav
# ./follow/4cee0c60_nohash_0.wav
# ./follow/578d3efb_nohash_1.wav
# ./follow/d5b963aa_nohash_2.wav
# ./follow/f68160c0_nohash_4.wav
# ./follow/017c4098_nohash_3.wav
# ./follow/02ade946_nohash_0.wav
# ./follow/0d6d7360_nohash_1.wav
# ./follow/f2e9b610_nohash_1.wav
# ./follow/a434d52e_nohash_0.wav
# ./follow/b2c1ad13_nohash_0.wav
# ./follow/6ef407da_nohash_0.wav
# ./follow/db24628d_nohash_3.wav
# ./follow/b528edb3_nohash_2.wav
# ./follow/1acc97de_nohash_1.wav
# ./follow/ce0cb033_nohash_2.wav
# ./follow/837a0f64_nohash_1.wav
# ./follow/ef77b778_nohash_1.wav
# ./follow/067f61e2_nohash_3.wav
# ./follow/b76f6088_nohash_0.wav
# ./follow/bbc30633_nohash_2.wav
# ./follow/c2dccf38_nohash_1.wav
# ./follow/ca4912b6_nohash_4.wav
# ./follow/3d794813_nohash_1.wav
# ./follow/2927c601_nohash_2.wav
# ./follow/2aca1e72_nohash_2.wav
# ./follow/ceef6d96_nohash_3.wav

# %%
# Create audio_processor
# TODO: Replace the below line with the location specified in the above command.
Audio_dataset = "/scratch/megankuo/Project4/Lab4/speech_commands"
audio_processor = data_proc.AudioProcessor(data_dir=Audio_dataset)
print("Audio_processor created")

# Define device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'Using {device} to run the training scrpit.')

# Define data loaders
from src.loaders import make_data_loaders
data_loaders = make_data_loaders(audio_processor, device)
train_loader = data_loaders['training']
test_loader = data_loaders['testing']
valid_loader = data_loaders['validation']

# Create a full precision (float32) TinyConv model
from src.networks import TinyConv
model_fp32 = TinyConv(model_settings=audio_processor.model_settings, \
    n_input=1, n_output=audio_processor.num_labels)

model_fp32

# Calculate the number of weights/parameters in this model
num_params = sum(p.numel() for p in model_fp32.parameters() if p.requires_grad)
print("Total number of trainable parameters: ", num_params / float(1e6), "M")
# Out:
# Audio_processor created
# Using cuda to run the training scrpit.
# Train size: 10556 Val size: 1333 Test size: 1368
# Total number of trainable parameters:  0.016652 M

# %% [markdown]
# ### Load Pretrained Model for Quantization Aware Finetuning
#
# In this notebook, we will load the trained 32-bits float model to finetune it in a quantization-aware way.

# %%
# !ls {TORCH_DIR}
# Out:
# fp32_finetune_checkpoint.pt  tinyconv_float32_init_seed0_89.47%_0.pt
# quant_checkpoint.pt

# %% [markdown]
# ### TODO 7: Replace the torch_path model with the trained model path.
#
# You can find the name of your file in `TORCH_DIR` under the folder icon to the left. (Or from running the tab above).

# %%
TORCH_DIR="/scratch/megankuo/Project4/Lab4/models/torch_models"
torch_path = os.path.join(TORCH_DIR, "tinyconv_float32_init_seed0_89.47%_0.pt")
torch_path
# Out:
# '/scratch/megankuo/Project4/Lab4/models/torch_models/tinyconv_float32_init_seed0_89.47%_0.pt'

# %%
os.path.exists(torch_path)
# Load model
model_fp32.load_state_dict(torch.load(torch_path))
model_fp32
# Out:
# /tmp/ipykernel_690470/503780442.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_fp32.load_state_dict(torch.load(torch_path))
# TinyConv(
#   (conv_reshape): Reshape(output_shape=(-1, 1, 49, 40))
#   (conv): Conv2d(1, 8, kernel_size=(10, 8), stride=(2, 2), padding=(5, 3))
#   (relu): ReLU()
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc_reshape): Reshape(output_shape=(-1, 4000))
#   (fc): Linear(in_features=4000, out_features=4, bias=True)
#   (softmax): Softmax(dim=1)
# )

# %% [markdown]
# ### Define settings for weight and activation quantization

# %%
# We choose 4 bit quantization as an example because accuracy improvements will 
# be more obvious with 4-bit or lower bit quantization
QUANT_BITS = 4
# Settings for activations quantization: n-bit asymmetric quantization
a_qconfig = QConfig(quant_bits=QUANT_BITS, is_symmetric=False)
# Settings for weights quantization: n-bit symmetric quantization
w_qconfig = QConfig(quant_bits=QUANT_BITS, is_symmetric=True)
# Settings for bias quantization: n-bit symmetric quantization
b_qconfig = QConfig(quant_bits=QUANT_BITS, is_symmetric=True)

# %% [markdown]
# ### Prepare quantization aware training model

# %%
from src.quant import quantize_model
qat_model_nbit = quantize_model(
    model_fp32, a_qconfig=a_qconfig, w_qconfig=w_qconfig, b_qconfig=b_qconfig)

# Print to see the model prepared for QAT
print(qat_model_nbit)
# Out:
# TinyConv(
#   (conv_reshape): Reshape(output_shape=(-1, 1, 49, 40))
#   (conv): QuantWrapper(
#     (module): Conv2d(1, 8, kernel_size=(10, 8), stride=(2, 2), padding=(5, 3))
#   	(activation): quant_bits=4, quant_mode=asymmetric, prev_scale=None, prev_zeropoint=None, prev_min=None, prev_max=None
#   	(weight): quant_bits=4, quant_mode=symmetric, prev_scale=None, prev_zeropoint=None, prev_min=None, prev_max=None
#   	(bias): quant_bits=4, quant_mode=symmetric, prev_scale=None, prev_zeropoint=None, prev_min=None, prev_max=None
#   )
#   (relu): ReLU()
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc_reshape): Reshape(output_shape=(-1, 4000))
#   (fc): QuantWrapper(
#     (module): Linear(in_features=4000, out_features=4, bias=True)
#   	(activation): quant_bits=4, quant_mode=asymmetric, prev_scale=None, prev_zeropoint=None, prev_min=None, prev_max=None
#   	(weight): quant_bits=4, quant_mode=symmetric, prev_scale=None, prev_zeropoint=None, prev_min=None, prev_max=None
#   	(bias): quant_bits=4, quant_mode=symmetric, prev_scale=None, prev_zeropoint=None, prev_min=None, prev_max=None
#   )
#   (softmax): Softmax(dim=1)
# )

# %% [markdown]
# ##  1.6 Perform Quantization Aware Training (5 pts)
#
# In this training, we will finetune the 32-bits float pretrained model. The goal is to finetune the weights of the 32-bits float model such that the resulted model will have better accuracy after quantization.

# %%
import time
from src.train_val_test_utils import train, test
from src.train_val_test_utils import create_optimizer


def run_training(model, data_loaders, n_epoch, log_interval, optimizer, scheduler=None, 
                 save_interval=1, resume=True, checkpoint_path=None, verbose=False):
    test_loader = data_loaders['testing']
    with tqdm(total=n_epoch) as pbar:
        completed_epoch = 1
        if resume:
            try:
                #continue training with previous model if one exists
                if checkpoint_path is None:
                    raise ValueError
                checkpoint = torch.load(checkpoint_path)
                model.load_state_dict(checkpoint['model_state_dict'])
                optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
                if scheduler is not None:
                    scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
                completed_epoch = checkpoint["epoch"] + 1
                model.eval()
                pbar.update(completed_epoch)
            except:
                pass

        for epoch in range(completed_epoch, n_epoch + 1):
            train_iters = len(data_loaders['training'])
            train(model, data_loaders, optimizer, epoch, device, verbose)
            test(test_loader, model, device, 
                 epoch=None, loader_type='Test')
            
            if scheduler is not None:
                scheduler.step()
            #checkpoint the model every run
            if epoch % save_interval == 0 and checkpoint_path is not None:
                torch.save({
                    'epoch': epoch,
                    'model_state_dict': model.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'scheduler_state_dict': scheduler.state_dict() if scheduler is not None else None
                }, checkpoint_path)
                
            # Update epoch pbar
            pbar.update(1)


verbose = False
log_interval = 100
num_batches = len(train_loader)
n_epoch = 30
print(f'#batches: {num_batches} \n#epochs: {n_epoch} \n#total training steps: {num_batches * n_epoch}')

# Create optimizer
optimizer_quant = create_optimizer(model=qat_model_nbit, learning_rate=0.001)
print(optimizer_quant.state_dict())

checkpoint_path = os.path.join(TORCH_DIR, "quant_checkpoint.pt")
qat_model_nbit.to(device)
run_training(
    model=qat_model_nbit, data_loaders=data_loaders, 
    n_epoch=n_epoch, log_interval=log_interval, 
    optimizer=optimizer_quant, scheduler=None, 
    resume=False,
    checkpoint_path=checkpoint_path,
    verbose=verbose
)
# Out:
# #batches: 106
# #epochs: 30
# #total training steps: 3180
# {'state': {}, 'param_groups': [{'lr': 0.001, 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0.0001, 'amsgrad': False, 'maximize': False, 'foreach': None, 'capturable': False, 'differentiable': False, 'fused': None, 'params': [0, 1, 2, 3]}]}
#   0%|          | 0/30 [00:00<?, ?it/s]
# Val Acc Epoch 1 = 85.07%, Train loss = 2.094
# Val Acc Epoch 2 = 84.55%, Train loss = 0.45
# Val Acc Epoch 3 = 83.87%, Train loss = 0.577
# Val Acc Epoch 4 = 86.95%, Train loss = 0.473
# Val Acc Epoch 5 = 88.07%, Train loss = 0.457
# Val Acc Epoch 6 = 87.55%, Train loss = 0.455
# Val Acc Epoch 7 = 87.02%, Train loss = 0.457
# Val Acc Epoch 8 = 87.02%, Train loss = 0.443
# Val Acc Epoch 9 = 85.37%, Train loss = 0.439
# Val Acc Epoch 10 = 88.22%, Train loss = 0.415
# Val Acc Epoch 11 = 86.2%, Train loss = 0.431
# Val Acc Epoch 12 = 86.95%, Train loss = 0.436
# Val Acc Epoch 13 = 87.25%, Train loss = 0.438
# Val Acc Epoch 14 = 85.07%, Train loss = 0.427
# Val Acc Epoch 15 = 86.72%, Train loss = 0.435
# Val Acc Epoch 16 = 86.35%, Train loss = 0.436
# Val Acc Epoch 17 = 86.57%, Train loss = 0.437
# Val Acc Epoch 18 = 87.25%, Train loss = 0.448
# Val Acc Epoch 19 = 84.4%, Train loss = 0.449
# Val Acc Epoch 20 = 87.55%, Train loss = 0.442
# Val Acc Epoch 21 = 86.35%, Train loss = 0.443
# Val Acc Epoch 22 = 85.07%, Train loss = 0.457
# Val Acc Epoch 23 = 86.65%, Train loss = 0.442
# Val Acc Epoch 24 = 86.8%, Train loss = 0.447
# Val Acc Epoch 25 = 85.75%, Train loss = 0.442
# Val Acc Epoch 26 = 87.25%, Train loss = 0.455
# Val Acc Epoch 27 = 87.7%, Train loss = 0.467
# Val Acc Epoch 28 = 86.5%, Train loss = 0.458
# Val Acc Epoch 29 = 86.8%, Train loss = 0.464
# Val Acc Epoch 30 = 84.62%, Train loss = 0.473

# %% [markdown]
# For fair comparison, we conduct the same finetuning for the float model.

# %%
# Create optimizer
optimizer_fp32 = create_optimizer(model=model_fp32, learning_rate=0.0001)

checkpoint_path = os.path.join(TORCH_DIR, "fp32_finetune_checkpoint.pt")
model_fp32.to(device)
run_training(
    model=model_fp32, data_loaders=data_loaders, 
    n_epoch=n_epoch, log_interval=log_interval, 
    optimizer=optimizer_fp32, scheduler=None, 
    resume=False,
    checkpoint_path=checkpoint_path,
    verbose=verbose
)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Val Acc Epoch 1 = 90.7%, Train loss = 0.318
# Val Acc Epoch 2 = 90.1%, Train loss = 0.324
# Val Acc Epoch 3 = 90.62%, Train loss = 0.317
# Val Acc Epoch 4 = 89.87%, Train loss = 0.324
# Val Acc Epoch 5 = 91.15%, Train loss = 0.32
# Val Acc Epoch 6 = 90.32%, Train loss = 0.311
# Val Acc Epoch 7 = 90.1%, Train loss = 0.318
# Val Acc Epoch 8 = 90.55%, Train loss = 0.318
# Val Acc Epoch 9 = 90.62%, Train loss = 0.308
# Val Acc Epoch 10 = 90.62%, Train loss = 0.301
# Val Acc Epoch 11 = 90.7%, Train loss = 0.308
# Val Acc Epoch 12 = 91.37%, Train loss = 0.306
# Val Acc Epoch 13 = 90.25%, Train loss = 0.304
# Val Acc Epoch 14 = 91.37%, Train loss = 0.303
# Val Acc Epoch 15 = 90.92%, Train loss = 0.293
# Val Acc Epoch 16 = 91.0%, Train loss = 0.299
# Val Acc Epoch 17 = 91.3%, Train loss = 0.302
# Val Acc Epoch 18 = 90.55%, Train loss = 0.304
# Val Acc Epoch 19 = 91.07%, Train loss = 0.294
# Val Acc Epoch 20 = 90.85%, Train loss = 0.296
# Val Acc Epoch 21 = 91.6%, Train loss = 0.296
# Val Acc Epoch 22 = 90.7%, Train loss = 0.297
# Val Acc Epoch 23 = 90.92%, Train loss = 0.298
# Val Acc Epoch 24 = 90.7%, Train loss = 0.296
# Val Acc Epoch 25 = 91.82%, Train loss = 0.293
# Val Acc Epoch 26 = 91.45%, Train loss = 0.291
# Val Acc Epoch 27 = 90.47%, Train loss = 0.297
# Val Acc Epoch 28 = 91.37%, Train loss = 0.3
# Val Acc Epoch 29 = 90.92%, Train loss = 0.298
# Val Acc Epoch 30 = 90.55%, Train loss = 0.293

# %% [markdown]
# ## 1.7 Testing

# %% [markdown]
# We will compute the accuracy of the finetuned model in train/val/test set in this section.
# Note that this is not the final accuracy we want the model to perform well on.
# We would like our quantized-aware-finetuned model to perform well when quantized into integer.
# But the training/validation/testing accuracy of these model in quantization simulation model is still worth looking at for sanity checking purpose.

# %%
from src.train_val_test_utils import plot_acc

test_time_data_loaders = make_data_loaders(
    audio_processor, device, 
    test_batch_size=1, valid_batch_size=1,
    num_workers=0
)

plot_acc(
    test_time_data_loaders['training'], qat_model_nbit, audio_processor, device,
    "Training", 'n-bit Quantized TinyConv', "float")
plot_acc(
    test_time_data_loaders['validation'], qat_model_nbit, audio_processor, device,
    "Validation", 'n-bit Quantized TinyConv', "float")
plot_acc(
    test_time_data_loaders['testing'], qat_model_nbit, audio_processor, device,
    'Testing', 'n-bit Quantized TinyConv', "float")
# Out:
# Train size: 10556 Val size: 1333 Test size: 1368
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[19], line 9
#       1 from src.train_val_test_utils import plot_acc
#       3 test_time_data_loaders = make_data_loaders(
#       4     audio_processor, device,
#       5     test_batch_size=1, valid_batch_size=1,
#       6     num_workers=0
#       7 )
# ----> 9 plot_acc(
#      10     test_time_data_loaders['training'], qat_model_nbit, audio_processor, device,
#      11     "Training", 'n-bit Quantized TinyConv', "float")
#      12 plot_acc(
#      13     test_time_data_loaders['validation'], qat_model_nbit, audio_processor, device,
#      14     "Validation", 'n-bit Quantized TinyConv', "float")
#      15 plot_acc(
#      16     test_time_data_loaders['testing'], qat_model_nbit, audio_processor, device,
#      17     'Testing', 'n-bit Quantized TinyConv', "float")
#
# File /scratch/megankuo/Project4/Lab4/src/train_val_test_utils.py:61, in plot_acc(test_loader, model, audio_processor, device, which_set, model_name, model_type)
#      59 def plot_acc(test_loader, model, audio_processor, device, which_set='testing',
#      60              model_name='model', model_type="float"):
# ---> 61     correct_list, total_list = test_model(
#      62         model, test_loader, audio_processor, model_type=model_type, device=device)
#      63     title = f'{which_set} accuracy for {model_name}'
#      64     plot_test_results(correct_list, total_list, audio_processor, title)
#
# File /scratch/megankuo/Project4/Lab4/src/train_val_test_utils.py:70, in test_model(model, test_loader, audio_processor, model_type, device)
#      68 def test_model(model, test_loader, audio_processor, model_type="float", device='cpu'):
#      69     assert model_type in ["float", "half", "double"], f"model type {model_type} is not supported"
# ---> 70     model = copy.deepcopy(model)
#      71     if model_type == "float":
#      72         model.float()
#
# File /usr/lib64/python3.11/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File /usr/lib64/python3.11/copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if state is not None:
#     270     if deep:
# --> 271         state = deepcopy(state, memo)
#     272     if hasattr(y, '__setstate__'):
#     273         y.__setstate__(state)
#
# File /usr/lib64/python3.11/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File /usr/lib64/python3.11/copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File /usr/lib64/python3.11/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File /usr/lib64/python3.11/copy.py:297, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     295     for key, value in dictiter:
#     296         key = deepcopy(key, memo)
# --> 297         value = deepcopy(value, memo)
#     298         y[key] = value
#     299 else:
#
# File /usr/lib64/python3.11/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File /usr/lib64/python3.11/copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if state is not None:
#     270     if deep:
# --> 271         state = deepcopy(state, memo)
#     272     if hasattr(y, '__setstate__'):
#     273         y.__setstate__(state)
#
# File /usr/lib64/python3.11/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File /usr/lib64/python3.11/copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File /usr/lib64/python3.11/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File /usr/lib64/python3.11/copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if state is not None:
#     270     if deep:
# --> 271         state = deepcopy(state, memo)
#     272     if hasattr(y, '__setstate__'):
#     273         y.__setstate__(state)
#
# File /usr/lib64/python3.11/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File /usr/lib64/python3.11/copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File /usr/lib64/python3.11/copy.py:153, in deepcopy(x, memo, _nil)
#     151 copier = getattr(x, "__deepcopy__", None)
#     152 if copier is not None:
# --> 153     y = copier(memo)
#     154 else:
#     155     reductor = dispatch_table.get(cls)
#
# File /scratch/megankuo/lab4/lib64/python3.11/site-packages/torch/_tensor.py:87, in Tensor.__deepcopy__(self, memo)
#      85     return handle_torch_function(Tensor.__deepcopy__, (self,), self, memo)
#      86 if not self.is_leaf:
# ---> 87     raise RuntimeError(
#      88         "Only Tensors created explicitly by the user "
#      89         "(graph leaves) support the deepcopy protocol at the moment.  "
#      90         "If you were attempting to deepcopy a module, this may be because "
#      91         "of a torch.nn.utils.weight_norm usage, "
#      92         "see https://github.com/pytorch/pytorch/pull/103001"
#      93     )
#      94 if id(self) in memo:
#      95     return memo[id(self)]
#
# RuntimeError: Only Tensors created explicitly by the user (graph leaves) support the deepcopy protocol at the moment.  If you were attempting to deepcopy a module, this may be because of a torch.nn.utils.weight_norm usage, see https://github.com/pytorch/pytorch/pull/103001

# %%
plot_acc(
    test_time_data_loaders['training'], model_fp32, audio_processor, device,
    "Training", 'FP32 FT TinyConv', "float")
plot_acc(
    test_time_data_loaders['validation'], model_fp32, audio_processor, device,
    "Validation", 'FP32 FT TinyConv', "float")
acc = plot_acc(
    test_time_data_loaders['testing'], model_fp32, audio_processor, device,
    'Testing', 'FP32 FT TinyConv', "float")

# %% [markdown]
# ## 1.8 Saving the Trained Model

# %%
from src.train_val_test_utils import choose_name
from src.quant import dequantize_model

# Save the qat model
qat_model_nbit_float = dequantize_model(qat_model_nbit)
file_name = choose_name("quant")
# You can also define your own path
qat_torch_path = os.path.join(TORCH_DIR, f'(QAT{QUANT_BITS}bit){file_name}.pt')
# Save the trained n-bit qat pytorch model to PATH
torch.save(qat_model_nbit.state_dict(), qat_torch_path)
qat_torch_path

# %% [markdown]
# ## 1.9 Understanding and Evaluate the Effectiveness of Quantization-Aware Training (QAT) (5 pts)

# %% [markdown]
# ### Model conversion: Quantized/Float Fine-tuning Model Converted to Integer Models

# %%
from src.quant import dequantize_model
from src.quant_conversion import convert_to_int

# %%
# Convert to quantized model
# Here, we convert the model to int16 rather then int4 or int8. We do this because the layer outputs are not quantized to int4 or int8. 
# Thus, completely making the model int8/int4 will require more modifications to the quantization process.

# Quantized integer model of qat_model_nbit (quantized aware finetuning model)
int_model_nbit = convert_to_int(
    qat_model_nbit, QUANT_BITS, dtype=torch.int16) 
    
# Post quantized model of model_fp32 (full-precision finetuned model)
post_quant_model = convert_to_int(
    model_fp32, QUANT_BITS, dtype=torch.int16) 
  
# Floating point models of the qat_model_nbit, without QuantWrappers
float_model_nbit = dequantize_model(qat_model_nbit)
print("============")
print(int_model_nbit)

# %%
from src.quant_conversion import print_features

# Select a sample data to see the features of it
sample_data, _ = audio_processor.get_data_from_file(
    audio_processor.data_index['testing'][0], BACKGROUND_FREQUENCY,
    BACKGROUND_VOLUME_RANGE, TIME_SHIFT_SAMPLE, 'testing')

print("=" * 80)
print("Features from Quantized QAT Model")
print("-" * 80)
print_features(sample_data, int_model_nbit, 'Quantized QAT Model')
print()
print("=" * 80)
print("Features from Model fp32")
print("-" * 80)
print_features(sample_data, model_fp32, "Model fp32")

# %% [markdown]
# ### Compare the Performance Between Integer Models from Float/Quantized-Aware Finetuning (7 pts)

# %%
from src.quant_conversion import compare_model, compare_model_mse

# Compare differences in predictions
# QAT trained floating point model vs. integer model converted from the QAT model 
# Percentage of same predictions shows how "quantization aware" the float point model is 
_ = compare_model(test_loader, float_model_nbit, int_model_nbit)
_ = compare_model_mse(test_loader, float_model_nbit, int_model_nbit)

# %%
from src.quant_conversion import compare_model, compare_model_mse

# Float32 model vs. integer model converted from the float32 model using post training quantization
_ = compare_model(test_loader, model_fp32, post_quant_model)
_ = compare_model_mse(test_loader, model_fp32, post_quant_model)

# %% [markdown]
# ### <center>This marks the end of part 1 the lab</center>
